# %% [markdown]
# # Part I : Data Collection - REE API

# %% [markdown]
# The objective of this session is to understand how data can be retrieved from specific sources as REE API.
#
# To do so, we will use `requests` library and `json` libraries for Python. These libraries are very famous and common python libraries to deal with http request and json file serialization.
#
# Later on, we will use specific libraries for plotting as `matplotlib` and `datetime`.

# %%
# import requests library
import requests 
import json
# import plotting library
import matplotlib
import matplotlib.pyplot as plt 
from datetime import date, datetime, timedelta

# %% [markdown]
# ### Create the request

# %% [markdown]
# As we have seen before, when we work with APIs, we have to know and hold the URL of the exposed **endpoint** of the server where the information we want is stored. We have to start writing the whole http request to be made. Following concepts explained in class, this will include: an http method, the desired endpoint, headers and parameters.
# Reading the available API documentation (mandatory) available here https://www.ree.es/es/apidatos you can understand that only GET request can be done.
#
# Let's therefore write in our script the desired headers/parameters.
# We need to write also the folder/section we want to access. Note that we can have the same endpoint but different sections from where to get the information.
#
# Most of the times, we need to add some headers to our requests that are required to get the information. The most important one is the **Authorization**, which corresponds to our ID to access that API.
#
# The following code is created only to facilitate the process of the API request generation. Endpoints, archives and headers are always provided in the API documentation, which have to be read.

# %%
endpoint = 'https://apidatos.ree.es'

get_archives = '/en/datos/mercados/precios-mercados-tiempo-real'

headers = {'Accept': 'application/json',
           'Content-Type': 'application/json',
           'Host': 'apidatos.ree.es'}

params = {'start_date': '2021-11-01T00:00', 'end_date': '2021-11-02T00:00', 'time_trunc':'hour'}

# %% [markdown]
# We are now looking at data regarding the **precios-mercados-tiempo-real** (look at the request archive above). We will find out what this archives contains once we have transferred the data.

# %% [markdown]
# We can write now the request according to the `requests` library and its `get` method. That is how you create a GET HTTP method with this library, which is very intuitive and easy to use.

# %%
response = requests.get(endpoint+get_archives, headers=headers, params=params)

# %% [markdown]
# After that, we can check if the request is correct or not according to the response we get from the API.

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# In this case, the response we get is **200**, meaning that is has been accepted and the connection is established.
# There are different codes that tell us which is our connection status between us and the API. Please, have a look yourself at the possible outcomes of http request.

# %%
status = response.status_code

#Check the status code
if status < 200:
    print('informational')
    # If the status code is 200, treat the information.
elif status >= 200 and status < 300:
    print('Connection is established')
    #okBehavior(response) # runs the function to get list of archives
elif status >= 300 and status < 400:
    print('redirection')
elif status >= 400 and status < 500:
    print('client error')
else:
    print('server error')
# Out:
# Connection is established

# %% [markdown]
# ### Access the data

# %% [markdown]
# The data are sent under the form of a json file. By calling the `json` method on the request object, we can access and store the transferred data. Have a look at all the IDs available for us to obtain data.

# %%
# accessing data by means of a json object
data_json = response.json()

# %%
data_json
# Out:
# {'data': {'type': 'Precios mercado peninsular en tiempo real',
#   'id': 'mer13',
#   'attributes': {'title': 'Precios mercado peninsular en tiempo real',
#    'last-update': '2023-05-19T08:50:06.000+02:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'PVPC',
#    'id': '1001',
#    'groupId': None,
#    'attributes': {'title': 'PVPC',
#     'description': None,
#     'color': '#ffcf09',
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2023-05-19T08:50:06.000+02:00',
#     'values': [{'value': 116.38,
#       'percentage': 0.5974025974025974,
#       'datetime': '2021-11-01T00:00:00.000+01:00'},
#      {'value': 90.29,
#       'percentage': 0.6211902304781561,
#       'datetime': '2021-11-01T01:00:00.000+01:00'},
#      {'value': 78.75,
#       'percentage': 0.6419662509170946,
#       'datetime': '2021-11-01T02:00:00.000+01:00'},
#      {'value': 55.28,
#       'percentage': 0.7148583990689255,
#       'datetime': '2021-11-01T03:00:00.000+01:00'},
#      {'value': 48.11,
#       'percentage': 0.7623197591506893,
#       'datetime': '2021-11-01T04:00:00.000+01:00'},
#      {'value': 78.37,
#       'percentage': 0.6560354930520677,
#       'datetime': '2021-11-01T05:00:00.000+01:00'},
#      {'value': 96.4,
#       'percentage': 0.6231818475661,
#       'datetime': '2021-11-01T06:00:00.000+01:00'},
#      {'value': 115.06,
#       'percentage': 0.5974039460020768,
#       'datetime': '2021-11-01T07:00:00.000+01:00'},
#      {'value': 126.32,
#       'percentage': 0.5871798447450378,
#       'datetime': '2021-11-01T08:00:00.000+01:00'},
#      {'value': 120.93,
#       'percentage': 0.5860431306033438,
#       'datetime': '2021-11-01T09:00:00.000+01:00'},
#      {'value': 112.4,
#       'percentage': 0.574642126789366,
#       'datetime': '2021-11-01T10:00:00.000+01:00'},
#      {'value': 106.24,
#       'percentage': 0.5756705499864535,
#       'datetime': '2021-11-01T11:00:00.000+01:00'},
#      {'value': 106.85,
#       'percentage': 0.5749878921595006,
#       'datetime': '2021-11-01T12:00:00.000+01:00'},
#      {'value': 97.26,
#       'percentage': 0.5793423874195854,
#       'datetime': '2021-11-01T13:00:00.000+01:00'},
#      {'value': 85.58,
#       'percentage': 0.586485745614035,
#       'datetime': '2021-11-01T14:00:00.000+01:00'},
#      {'value': 99.64,
#       'percentage': 0.5805173619202983,
#       'datetime': '2021-11-01T15:00:00.000+01:00'},
#      {'value': 118.75,
#       'percentage': 0.5828220858895705,
#       'datetime': '2021-11-01T16:00:00.000+01:00'},
#      {'value': 172.94,
#       'percentage': 0.5618035928921807,
#       'datetime': '2021-11-01T17:00:00.000+01:00'},
#      {'value': 226.97,
#       'percentage': 0.553625875064029,
#       'datetime': '2021-11-01T18:00:00.000+01:00'},
#      {'value': 220.7,
#       'percentage': 0.5509236145781328,
#       'datetime': '2021-11-01T19:00:00.000+01:00'},
#      {'value': 201.86,
#       'percentage': 0.5531320217021976,
#       'datetime': '2021-11-01T20:00:00.000+01:00'},
#      {'value': 189.16,
#       'percentage': 0.5552587548067045,
#       'datetime': '2021-11-01T21:00:00.000+01:00'},
#      {'value': 186.51,
#       'percentage': 0.5586138732478735,
#       'datetime': '2021-11-01T22:00:00.000+01:00'},
#      {'value': 173.15,
#       'percentage': 0.562084077260185,
#       'datetime': '2021-11-01T23:00:00.000+01:00'},
#      {'value': 150.42,
#       'percentage': 0.5751539020380071,
#       'datetime': '2021-11-02T00:00:00.000+01:00'}]}},
#   {'type': 'Spot market price',
#    'id': '600',
#    'groupId': None,
#    'attributes': {'title': 'Spot market price',
#     'description': None,
#     'color': '#df4a32',
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2021-11-01T14:01:13.000+01:00',
#     'values': [{'value': 78.43,
#       'percentage': 0.4025974025974026,
#       'datetime': '2021-11-01T00:00:00.000+01:00'},
#      {'value': 55.06,
#       'percentage': 0.3788097695218438,
#       'datetime': '2021-11-01T01:00:00.000+01:00'},
#      {'value': 43.92,
#       'percentage': 0.35803374908290536,
#       'datetime': '2021-11-01T02:00:00.000+01:00'},
#      {'value': 22.05,
#       'percentage': 0.28514160093107466,
#       'datetime': '2021-11-01T03:00:00.000+01:00'},
#      {'value': 15,
#       'percentage': 0.23768024084931072,
#       'datetime': '2021-11-01T04:00:00.000+01:00'},
#      {'value': 41.09,
#       'percentage': 0.34396450694793235,
#       'datetime': '2021-11-01T05:00:00.000+01:00'},
#      {'value': 58.29,
#       'percentage': 0.37681815243390004,
#       'datetime': '2021-11-01T06:00:00.000+01:00'},
#      {'value': 77.54,
#       'percentage': 0.40259605399792314,
#       'datetime': '2021-11-01T07:00:00.000+01:00'},
#      {'value': 88.81,
#       'percentage': 0.41282015525496213,
#       'datetime': '2021-11-01T08:00:00.000+01:00'},
#      {'value': 85.42,
#       'percentage': 0.4139568693966561,
#       'datetime': '2021-11-01T09:00:00.000+01:00'},
#      {'value': 83.2,
#       'percentage': 0.4253578732106339,
#       'datetime': '2021-11-01T10:00:00.000+01:00'},
#      {'value': 78.31,
#       'percentage': 0.42432945001354644,
#       'datetime': '2021-11-01T11:00:00.000+01:00'},
#      {'value': 78.98,
#       'percentage': 0.4250121078404994,
#       'datetime': '2021-11-01T12:00:00.000+01:00'},
#      {'value': 70.62,
#       'percentage': 0.4206576125804146,
#       'datetime': '2021-11-01T13:00:00.000+01:00'},
#      {'value': 60.34,
#       'percentage': 0.4135142543859649,
#       'datetime': '2021-11-01T14:00:00.000+01:00'},
#      {'value': 72,
#       'percentage': 0.4194826380797017,
#       'datetime': '2021-11-01T15:00:00.000+01:00'},
#      {'value': 85,
#       'percentage': 0.4171779141104294,
#       'datetime': '2021-11-01T16:00:00.000+01:00'},
#      {'value': 134.89,
#       'percentage': 0.4381964071078192,
#       'datetime': '2021-11-01T17:00:00.000+01:00'},
#      {'value': 183,
#       'percentage': 0.4463741249359709,
#       'datetime': '2021-11-01T18:00:00.000+01:00'},
#      {'value': 179.9,
#       'percentage': 0.4490763854218672,
#       'datetime': '2021-11-01T19:00:00.000+01:00'},
#      {'value': 163.08,
#       'percentage': 0.44686797829780234,
#       'datetime': '2021-11-01T20:00:00.000+01:00'},
#      {'value': 151.51,
#       'percentage': 0.4447412451932956,
#       'datetime': '2021-11-01T21:00:00.000+01:00'},
#      {'value': 147.37,
#       'percentage': 0.4413861267521265,
#       'datetime': '2021-11-01T22:00:00.000+01:00'},
#      {'value': 134.9,
#       'percentage': 0.43791592273981494,
#       'datetime': '2021-11-01T23:00:00.000+01:00'},
#      {'value': 111.11,
#       'percentage': 0.4248460979619929,
#       'datetime': '2021-11-02T00:00:00.000+01:00'}]}}]}

# %% [markdown]
# For a better visualization of the json content, you can use this tool (https://jsonformatter.curiousconcept.com). This helps in understanding the structure of the json file and access the desired data.
# You can find out using the suggested tool that the response to the request contain the desired substructures.

# %% [markdown]
# The **data** struct contains meta-data about your request.
# The **included** struct contains the actual data.
# This contains 2 additional substructure:
#
#     - **PVPC** or Voluntary price for the small consumer - Precio Voluntario Pequeno Consumidor (€/MWh)
#     - "Precio mercado spot" or **Spot market price** (€/MWh)
#
# - PVPC is the price of energy for the REGULATED market
# - Spot market price is the price of energy for the FREE market
#
# Let's try to extract both.
#
# NB: The spot market price can be also called the "Day-Ahead Market" price (DAM) which is contracted the same day for the next one. Prices are defined for each hour.
#
# To access the actual values it is needed to access some more substructures ("attributes" and "values")

# %%
pvpc_data = data_json['included'][0]
spot_market_data = data_json['included'][1]

pvpc_values = pvpc_data['attributes']['values']
spot_values = spot_market_data['attributes']['values']

# %% [markdown]
# ### Store the data on local variables

# %% [markdown]
# Let's focus on the spot market price first.

# %%
spot_values
# Out:
# [{'value': 78.43,
#   'percentage': 0.4025974025974026,
#   'datetime': '2021-11-01T00:00:00.000+01:00'},
#  {'value': 55.06,
#   'percentage': 0.3788097695218438,
#   'datetime': '2021-11-01T01:00:00.000+01:00'},
#  {'value': 43.92,
#   'percentage': 0.35803374908290536,
#   'datetime': '2021-11-01T02:00:00.000+01:00'},
#  {'value': 22.05,
#   'percentage': 0.28514160093107466,
#   'datetime': '2021-11-01T03:00:00.000+01:00'},
#  {'value': 15,
#   'percentage': 0.23768024084931072,
#   'datetime': '2021-11-01T04:00:00.000+01:00'},
#  {'value': 41.09,
#   'percentage': 0.34396450694793235,
#   'datetime': '2021-11-01T05:00:00.000+01:00'},
#  {'value': 58.29,
#   'percentage': 0.37681815243390004,
#   'datetime': '2021-11-01T06:00:00.000+01:00'},
#  {'value': 77.54,
#   'percentage': 0.40259605399792314,
#   'datetime': '2021-11-01T07:00:00.000+01:00'},
#  {'value': 88.81,
#   'percentage': 0.41282015525496213,
#   'datetime': '2021-11-01T08:00:00.000+01:00'},
#  {'value': 85.42,
#   'percentage': 0.4139568693966561,
#   'datetime': '2021-11-01T09:00:00.000+01:00'},
#  {'value': 83.2,
#   'percentage': 0.4253578732106339,
#   'datetime': '2021-11-01T10:00:00.000+01:00'},
#  {'value': 78.31,
#   'percentage': 0.42432945001354644,
#   'datetime': '2021-11-01T11:00:00.000+01:00'},
#  {'value': 78.98,
#   'percentage': 0.4250121078404994,
#   'datetime': '2021-11-01T12:00:00.000+01:00'},
#  {'value': 70.62,
#   'percentage': 0.4206576125804146,
#   'datetime': '2021-11-01T13:00:00.000+01:00'},
#  {'value': 60.34,
#   'percentage': 0.4135142543859649,
#   'datetime': '2021-11-01T14:00:00.000+01:00'},
#  {'value': 72,
#   'percentage': 0.4194826380797017,
#   'datetime': '2021-11-01T15:00:00.000+01:00'},
#  {'value': 85,
#   'percentage': 0.4171779141104294,
#   'datetime': '2021-11-01T16:00:00.000+01:00'},
#  {'value': 134.89,
#   'percentage': 0.4381964071078192,
#   'datetime': '2021-11-01T17:00:00.000+01:00'},
#  {'value': 183,
#   'percentage': 0.4463741249359709,
#   'datetime': '2021-11-01T18:00:00.000+01:00'},
#  {'value': 179.9,
#   'percentage': 0.4490763854218672,
#   'datetime': '2021-11-01T19:00:00.000+01:00'},
#  {'value': 163.08,
#   'percentage': 0.44686797829780234,
#   'datetime': '2021-11-01T20:00:00.000+01:00'},
#  {'value': 151.51,
#   'percentage': 0.4447412451932956,
#   'datetime': '2021-11-01T21:00:00.000+01:00'},
#  {'value': 147.37,
#   'percentage': 0.4413861267521265,
#   'datetime': '2021-11-01T22:00:00.000+01:00'},
#  {'value': 134.9,
#   'percentage': 0.43791592273981494,
#   'datetime': '2021-11-01T23:00:00.000+01:00'},
#  {'value': 111.11,
#   'percentage': 0.4248460979619929,
#   'datetime': '2021-11-02T00:00:00.000+01:00'}]

# %% [markdown]
# Create local structure in your python environment and fill them with data

# %%
prices = []
times = []

# %%
for data_point in spot_values:
    #print(time_period['value'])
    prices.append(data_point['value'])
    times.append(data_point['datetime'])
    print(f"Spot price at {data_point['datetime']} is {data_point['value']} €/MWh")
# Out:
# Spot price at 2021-11-01T00:00:00.000+01:00 is 78.43 €/MWh
# Spot price at 2021-11-01T01:00:00.000+01:00 is 55.06 €/MWh
# Spot price at 2021-11-01T02:00:00.000+01:00 is 43.92 €/MWh
# Spot price at 2021-11-01T03:00:00.000+01:00 is 22.05 €/MWh
# Spot price at 2021-11-01T04:00:00.000+01:00 is 15 €/MWh
# Spot price at 2021-11-01T05:00:00.000+01:00 is 41.09 €/MWh
# Spot price at 2021-11-01T06:00:00.000+01:00 is 58.29 €/MWh
# Spot price at 2021-11-01T07:00:00.000+01:00 is 77.54 €/MWh
# Spot price at 2021-11-01T08:00:00.000+01:00 is 88.81 €/MWh
# Spot price at 2021-11-01T09:00:00.000+01:00 is 85.42 €/MWh
# Spot price at 2021-11-01T10:00:00.000+01:00 is 83.2 €/MWh
# Spot price at 2021-11-01T11:00:00.000+01:00 is 78.31 €/MWh
# Spot price at 2021-11-01T12:00:00.000+01:00 is 78.98 €/MWh
# Spot price at 2021-11-01T13:00:00.000+01:00 is 70.62 €/MWh
# Spot price at 2021-11-01T14:00:00.000+01:00 is 60.34 €/MWh
# Spot price at 2021-11-01T15:00:00.000+01:00 is 72 €/MWh
# Spot price at 2021-11-01T16:00:00.000+01:00 is 85 €/MWh
# Spot price at 2021-11-01T17:00:00.000+01:00 is 134.89 €/MWh
# Spot price at 2021-11-01T18:00:00.000+01:00 is 183 €/MWh
# Spot price at 2021-11-01T19:00:00.000+01:00 is 179.9 €/MWh
# Spot price at 2021-11-01T20:00:00.000+01:00 is 163.08 €/MWh
# Spot price at 2021-11-01T21:00:00.000+01:00 is 151.51 €/MWh
# Spot price at 2021-11-01T22:00:00.000+01:00 is 147.37 €/MWh
# Spot price at 2021-11-01T23:00:00.000+01:00 is 134.9 €/MWh
# Spot price at 2021-11-02T00:00:00.000+01:00 is 111.11 €/MWh

# %% [markdown]
# Now that is what we have

# %%
prices
# Out:
# [78.43,
#  55.06,
#  43.92,
#  22.05,
#  15,
#  41.09,
#  58.29,
#  77.54,
#  88.81,
#  85.42,
#  83.2,
#  78.31,
#  78.98,
#  70.62,
#  60.34,
#  72,
#  85,
#  134.89,
#  183,
#  179.9,
#  163.08,
#  151.51,
#  147.37,
#  134.9,
#  111.11]

# %%
times
# Out:
# ['2021-11-01T00:00:00.000+01:00',
#  '2021-11-01T01:00:00.000+01:00',
#  '2021-11-01T02:00:00.000+01:00',
#  '2021-11-01T03:00:00.000+01:00',
#  '2021-11-01T04:00:00.000+01:00',
#  '2021-11-01T05:00:00.000+01:00',
#  '2021-11-01T06:00:00.000+01:00',
#  '2021-11-01T07:00:00.000+01:00',
#  '2021-11-01T08:00:00.000+01:00',
#  '2021-11-01T09:00:00.000+01:00',
#  '2021-11-01T10:00:00.000+01:00',
#  '2021-11-01T11:00:00.000+01:00',
#  '2021-11-01T12:00:00.000+01:00',
#  '2021-11-01T13:00:00.000+01:00',
#  '2021-11-01T14:00:00.000+01:00',
#  '2021-11-01T15:00:00.000+01:00',
#  '2021-11-01T16:00:00.000+01:00',
#  '2021-11-01T17:00:00.000+01:00',
#  '2021-11-01T18:00:00.000+01:00',
#  '2021-11-01T19:00:00.000+01:00',
#  '2021-11-01T20:00:00.000+01:00',
#  '2021-11-01T21:00:00.000+01:00',
#  '2021-11-01T22:00:00.000+01:00',
#  '2021-11-01T23:00:00.000+01:00',
#  '2021-11-02T00:00:00.000+01:00']

# %% [markdown]
# ### Plot the spot market price - DAM price

# %% [markdown]
# For a better plotting experience, it is convenient to have a proper data type. *times* is a list of strings. Actually it contains datetime data so we want to treat it as such. We need to use a python library called *datetime*

# %%
# Convert each string to datetime object
times = [datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%f%z") for date_str in times]

# %%
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
plt.style.use('ggplot')

plt.figure(figsize=(20,10))
plt.plot(times, prices, 'r', linewidth=1.5, marker='.')
plt.title(f"Spot market prices", fontsize=20)
plt.xlabel('Hour', fontsize=20 )
plt.ylabel('Price [€/MWh]', fontsize=20)
plt.show()

# %% [markdown]
# ### Changing Dates

# %% [markdown]
# We could try to change the dates and ask for more recent prices. Let's make a new request, changing the desired parameters:

# %%
params = {'start_date': '2022-11-01T00:00', 'end_date': '2022-11-15T00:00', 'time_trunc':'hour'}

# %%
response = requests.get(endpoint+get_archives, headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Let's repeat the process of extracting the data in a new structure (without plotting for brevity)

# %%
data_json_new = response.json()

# %%
pvpc_data_new = data_json_new['included'][0]
spot_market_data_new = data_json_new['included'][1]

pvpc_values_new = pvpc_data_new['attributes']['values']
spot_values_new = spot_market_data_new['attributes']['values']

# %% [markdown]
# Looking again at the spot market price only:

# %%
prices_new = []
times_new = []
for data_point in spot_values_new:
    prices_new.append(data_point['value'])
    times_new.append(data_point['datetime'])

# %% [markdown]
# Let's plot and compare the new data

# %%
plt.figure(figsize=(20,10))
plt.plot(prices_new, 'r', linewidth=1.5, marker='.')
plt.title(f"Spot market prices", fontsize=20)
plt.xlabel('Hour', fontsize=20 )
plt.ylabel('Price [€/MWh]', fontsize=20)
plt.show()

# %% [markdown]
# Let's look for the most updated price signals.
# We need to use teh python `datetime` library for this. The approach is to generate the actual time in UTC time coordinates and add the desired time step for the analysis. Spot market prices are generated today for tomorrow and are available from 12PM when the market closes. If you are running the code after your 12PM you should be able to see DAM prices for tomorrow.
#
# Mind that datetime objects have to be transformed into strings, follwing the required format specified in the parameters of the API documentation, otherwise it will not work.

# %%
start_date = datetime.now()
end_date = start_date + timedelta(hours=24)             # add one day to see prices for tomorrow
# transform into strings with a minute resolution
end_date = end_date.strftime('%Y-%m-%dT%H:%M')
start_date = start_date.strftime('%Y-%m-%dT%H:%M')
# check
end_date
# Out:
# '2025-01-04T15:00'

# %%
start_date
# Out:
# '2025-01-03T15:00'

# %% [markdown]
# Update the parameters of the API request with the new structures

# %%
params = {'start_date': start_date, 'end_date': end_date, 'time_trunc':'hour'}
response = requests.get(endpoint+get_archives, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %% [markdown]
# Extract values just as before

# %%
data_json = response.json()
data_json
# Out:
# {'data': {'type': 'Precios mercado peninsular en tiempo real',
#   'id': 'mer13',
#   'attributes': {'title': 'Precios mercado peninsular en tiempo real',
#    'last-update': '2025-01-02T20:46:04.000+01:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'PVPC',
#    'id': '1001',
#    'groupId': None,
#    'attributes': {'title': 'PVPC',
#     'description': None,
#     'color': '#ffcf09',
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2025-01-02T20:46:04.000+01:00',
#     'values': [{'value': 158.29,
#       'percentage': 0.5895124948791479,
#       'datetime': '2025-01-03T15:00:00.000+01:00'},
#      {'value': 176.3,
#       'percentage': 0.5886477462437396,
#       'datetime': '2025-01-03T16:00:00.000+01:00'},
#      {'value': 198.42,
#       'percentage': 0.5842412107649726,
#       'datetime': '2025-01-03T17:00:00.000+01:00'},
#      {'value': 269.73,
#       'percentage': 0.6432097293430309,
#       'datetime': '2025-01-03T18:00:00.000+01:00'},
#      {'value': 271.39,
#       'percentage': 0.6421304183229226,
#       'datetime': '2025-01-03T19:00:00.000+01:00'},
#      {'value': 271.65,
#       'percentage': 0.6423504374556632,
#       'datetime': '2025-01-03T20:00:00.000+01:00'},
#      {'value': 270.22,
#       'percentage': 0.64439357084943,
#       'datetime': '2025-01-03T21:00:00.000+01:00'},
#      {'value': 201.14,
#       'percentage': 0.5801222888786339,
#       'datetime': '2025-01-03T22:00:00.000+01:00'},
#      {'value': 193.38,
#       'percentage': 0.5863553668890237,
#       'datetime': '2025-01-03T23:00:00.000+01:00'}]}},
#   {'type': 'Spot market price',
#    'id': '600',
#    'groupId': None,
#    'attributes': {'title': 'Spot market price',
#     'description': None,
#     'color': '#df4a32',
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2025-01-03T14:10:47.000+01:00',
#     'values': [{'value': 110.22,
#       'percentage': 0.41048750512085214,
#       'datetime': '2025-01-03T15:00:00.000+01:00'},
#      {'value': 123.2,
#       'percentage': 0.41135225375626044,
#       'datetime': '2025-01-03T16:00:00.000+01:00'},
#      {'value': 141.2,
#       'percentage': 0.41575878923502735,
#       'datetime': '2025-01-03T17:00:00.000+01:00'},
#      {'value': 149.62,
#       'percentage': 0.3567902706569691,
#       'datetime': '2025-01-03T18:00:00.000+01:00'},
#      {'value': 151.25,
#       'percentage': 0.35786958167707744,
#       'datetime': '2025-01-03T19:00:00.000+01:00'},
#      {'value': 151.25,
#       'percentage': 0.3576495625443367,
#       'datetime': '2025-01-03T20:00:00.000+01:00'},
#      {'value': 149.12,
#       'percentage': 0.35560642915056995,
#       'datetime': '2025-01-03T21:00:00.000+01:00'},
#      {'value': 145.58,
#       'percentage': 0.41987771112136596,
#       'datetime': '2025-01-03T22:00:00.000+01:00'},
#      {'value': 136.42,
#       'percentage': 0.4136446331109764,
#       'datetime': '2025-01-03T23:00:00.000+01:00'},
#      {'value': 109.06,
#       'percentage': 1,
#       'datetime': '2025-01-04T00:00:00.000+01:00'},
#      {'value': 101,
#       'percentage': 1,
#       'datetime': '2025-01-04T01:00:00.000+01:00'},
#      {'value': 95.53,
#       'percentage': 1,
#       'datetime': '2025-01-04T02:00:00.000+01:00'},
#      {'value': 94.33,
#       'percentage': 1,
#       'datetime': '2025-01-04T03:00:00.000+01:00'},
#      {'value': 96.62,
#       'percentage': 1,
#       'datetime': '2025-01-04T04:00:00.000+01:00'},
#      {'value': 102.63,
#       'percentage': 1,
#       'datetime': '2025-01-04T05:00:00.000+01:00'},
#      {'value': 110.89,
#       'percentage': 1,
#       'datetime': '2025-01-04T06:00:00.000+01:00'},
#      {'value': 120.25,
#       'percentage': 1,
#       'datetime': '2025-01-04T07:00:00.000+01:00'},
#      {'value': 128.39,
#       'percentage': 1,
#       'datetime': '2025-01-04T08:00:00.000+01:00'},
#      {'value': 128.41,
#       'percentage': 1,
#       'datetime': '2025-01-04T09:00:00.000+01:00'},
#      {'value': 118.99,
#       'percentage': 1,
#       'datetime': '2025-01-04T10:00:00.000+01:00'},
#      {'value': 99,
#       'percentage': 1,
#       'datetime': '2025-01-04T11:00:00.000+01:00'},
#      {'value': 82.52,
#       'percentage': 1,
#       'datetime': '2025-01-04T12:00:00.000+01:00'},
#      {'value': 82.27,
#       'percentage': 1,
#       'datetime': '2025-01-04T13:00:00.000+01:00'},
#      {'value': 88.22,
#       'percentage': 1,
#       'datetime': '2025-01-04T14:00:00.000+01:00'},
#      {'value': 97.35,
#       'percentage': 1,
#       'datetime': '2025-01-04T15:00:00.000+01:00'}]}}]}

# %% [markdown]
# Let's extract the data we have

# %%
spot_price = data_json["included"][1]["attributes"]["values"][0]["value"]
time_str = data_json["included"][1]["attributes"]["values"][0]["datetime"]
# from string to datetime
time = datetime.strptime(time_str[:16], '%Y-%m-%dT%H:%M') 
print(f"Spot market price at {time} is {spot_price} €/MWh")
# Out:
# Spot market price at 2025-01-03 15:00:00 is 110.22 €/MWh

# %%
pvpc = data_json["included"][0]["attributes"]["values"][0]["value"]
time_str = data_json["included"][0]["attributes"]["values"][0]["datetime"]
# from string to datetime
time = datetime.strptime(time_str[:16], '%Y-%m-%dT%H:%M') 
print(f"Price the final consumer is paying at {time} is {pvpc} €/MWh")
# Out:
# Price the final consumer is paying at 2025-01-03 15:00:00 is 158.29 €/MWh

# %% [markdown]
# As you can see there is a big difference between the price settled by the regulator and the price in the free market!

# %% [markdown]
# **IMPORTANT**: asking dates prior to year 2021 will return partial data only. This is because there is a problem with the API.
#
# This changes do happen a lot in APIs, because as said they have their own software development cycle (ciclically need maintaince) and might be subjected to change. Do always check out the API documentation to keep trace of the changes.
# API are not perfect tools :) and might contain bugs, missing data, and many more...

# %% [markdown]
# # Part II: Exercize - REE API

# %% [markdown]
# ### Build your own request

# %% [markdown]
# Looking at the REE API documentation available online, you can see the several information available (called "widget").
# Each widget belong to a category. Pick the one of your interest and try to stream the desired data from the REE API.
# You would need to set proper parameters for each widget.
# It is important to have a deep look at the API documentation, looking for the type of information that might be of interest for you.
#
# Set your own request parameters here below:

# %%
endpoint = 'https://apidatos.ree.es'
# enter here your desired path to the resource
get_archives = '/en/datos/balance/balance-electrico'
headers = {'Accept': 'application/json',
           'Content-Type': 'application/json',
           'Host': 'apidatos.ree.es'}

params = {'start_date': '2024-01-01T00:00', 'end_date': '2025-01-01T00:00', 'time_trunc':'month'}
# choose here your desired parameters: start_date, end_date, time_trunc, geo_trunc, etc ...

# %% [markdown]
# Now you can make your own request

# %%
response = requests.get(endpoint+get_archives, headers=headers, params=params)

# %% [markdown]
# Check the status of your request

# %%
response
status = response.status_code

#Check the status code
if status < 200:
    print('informational')
    # If the status code is 200, treat the information.
elif status >= 200 and status < 300:
    print('Connection is established')
    #okBehavior(response) # runs the function to get list of archives
elif status >= 300 and status < 400:
    print('redirection')
elif status >= 400 and status < 500:
    print('client error')
else:
    print('server error')
# Out:
# Connection is established

# %% [markdown]
# Problem with your request? meaning any status different than 200.
# Check the problem related with your request and try to fix it. Use the following:

# %%
response.json()
# Out:
# {'data': {'type': 'Electrical energy balance',
#   'id': 'bal1',
#   'attributes': {'title': 'Electrical energy balance',
#    'last-update': '2024-12-10T12:17:40.000+01:00',
#    'description': "Electrical energy balance: Allocation of production units according to primary fuel. The self-consumption of manageable hydroelectric and non-renewable facilities is removed from their net production. In these types of generating facilities, a negative generation indicates that the hourly electricity consumption required by the power station for its operation exceeds the facility's hourly production."},
#   'meta': {'cache-control': {'cache': 'HIT',
#     'expireAt': '2025-02-02T10:37:44'}}},
#  'included': [{'type': 'Renovable',
#    'id': 'Renovable',
#    'attributes': {'title': 'Renovable',
#     'last-update': '2024-12-10T12:17:35.000+01:00',
#     'description': None,
#     'magnitude': None,
#     'content': [{'type': 'Hydro',
#       'id': '10288',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Hydro',
#        'description': '10288',
#        'color': '#0090d1',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:35.000+01:00',
#        'values': [{'value': 3928348.723999999,
#          'percentage': 0.3265764857208968,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 2984014.346999998,
#          'percentage': 0.22879458672163067,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 4670251.880000005,
#          'percentage': 0.3242435908799391,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 4032993.105000003,
#          'percentage': 0.29733063837930973,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 2920925.0129999975,
#          'percentage': 0.22009499462382692,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 2392878.3969999976,
#          'percentage': 0.1914406019331683,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 2120429.0580000007,
#          'percentage': 0.15971335305349874,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 1766632.8750000012,
#          'percentage': 0.14510061530044002,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 1610087.744999998,
#          'percentage': 0.14275317758401967,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 2850155.2300000014,
#          'percentage': 0.24097158684211673,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 2679552.893000001,
#          'percentage': 0.25982117148791994,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 2538797.899999999,
#          'percentage': 0.23512430081677657,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 2881.2,
#          'percentage': 0.4575597891146761,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 34497948.367}},
#      {'type': 'Wind',
#       'id': '10291',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Wind',
#        'description': '10291',
#        'color': '#6fb114',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:37.000+01:00',
#        'values': [{'value': 5719850.105000001,
#          'percentage': 0.475509858564482,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 6955950.069999999,
#          'percentage': 0.5333364844984604,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 6145698.504999998,
#          'percentage': 0.4266800598614974,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 4705770.005999999,
#          'percentage': 0.34693081875481835,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 4273305.3290000055,
#          'percentage': 0.321998376961493,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 4438999.936999998,
#          'percentage': 0.35513915834001186,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 4228487.663999998,
#          'percentage': 0.3184949482817338,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 3958539.712,
#          'percentage': 0.32513067996791706,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 4645341.194000008,
#          'percentage': 0.4118640232277812,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 5693734.748999994,
#          'percentage': 0.48138721817079033,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 4838652.635999996,
#          'percentage': 0.4691769285812081,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 5242122.785000006,
#          'percentage': 0.4854858492748952,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 2890.55,
#          'percentage': 0.45904465098758407,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 60849343.24199999}},
#      {'type': 'Solar photovoltaic',
#       'id': '1458',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Solar photovoltaic',
#        'description': '1458',
#        'color': '#e48500',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-02T07:59:55.000+01:00',
#        'values': [{'value': 1933001.348,
#          'percentage': 0.16069672818680147,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 2607020.991,
#          'percentage': 0.1998892166219405,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 3070347.168,
#          'percentage': 0.2131663166313785,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 4026261.541,
#          'percentage': 0.29683435679159004,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 5114478.197,
#          'percentage': 0.38538170143445444,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 4770018.588,
#          'percentage': 0.3816220794437314,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 5817473.554,
#          'percentage': 0.43817934115926155,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 5377001.291,
#          'percentage': 0.4416345958666482,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 4192002.287,
#          'percentage': 0.3716702078921347,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 2786064.435,
#          'percentage': 0.23555291335705075,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 2317466.447,
#          'percentage': 0.22471168556383758,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 2458287.821,
#          'percentage': 0.2276680649212064,
#          'datetime': '2024-12-01T00:00:00.000+01:00'}],
#        'total': 44469423.668000005}},
#      {'type': 'Thermal solar',
#       'id': '1459',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Thermal solar',
#        'description': '1459',
#        'color': '#ff0000',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:40.000+01:00',
#        'values': [{'value': 94242.967,
#          'percentage': 0.007834726275378005,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 176416.858,
#          'percentage': 0.01352648393176061,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 151740.955,
#          'percentage': 0.010534984706810116,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 443319.442,
#          'percentage': 0.03268353038650169,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 599701.686,
#          'percentage': 0.04518819852225698,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 494558.02,
#          'percentage': 0.03956677663118039,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 674743.076,
#          'percentage': 0.050822487416408386,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 671160.866,
#          'percentage': 0.0551251230520524,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 459924.606,
#          'percentage': 0.040777714854030124,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 153783.834,
#          'percentage': 0.013001935515506867,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 97175.563,
#          'percentage': 0.00942256772934624,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 125447.295,
#          'percentage': 0.011617981693710604,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 0.1,
#          'percentage': 1.5880875646073724e-05,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 4142215.268}},
#      {'type': 'Hydroeolian',
#       'id': '1455',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Hydroeolian',
#        'description': '1455',
#        'color': '#00FFFF',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:39.000+01:00',
#        'values': [{'value': 668.081,
#          'percentage': 5.553975995663223e-05,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 1414.679,
#          'percentage': 0.00010846827779972801,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 1589.155,
#          'percentage': 0.00011033094935873332,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 1294.547,
#          'percentage': 9.543990676423932e-05,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 2252.374,
#          'percentage': 0.00016971892164793754,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 2629.249,
#          'percentage': 0.00021035127059663172,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 3511.303,
#          'percentage': 0.0002644757076880282,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 3975.784,
#          'percentage': 0.0003265470222281719,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 2268.239,
#          'percentage': 0.00020110601162919825,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 1839.432,
#          'percentage': 0.00015551814275328724,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 252.982,
#          'percentage': 2.4530241510465656e-05,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 1962.372,
#          'percentage': 0.0001817400843298396,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 0.232,
#          'percentage': 3.684363149889104e-05,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 23658.429}},
#      {'type': 'Other renewables',
#       'id': '10292',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Other renewables',
#        'description': '10292',
#        'color': '#9a5cbc',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:38.000+01:00',
#        'values': [{'value': 283523.709,
#          'percentage': 0.023570253816339707,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 258476.49000000017,
#          'percentage': 0.019818276599863738,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 310117.7469999997,
#          'percentage': 0.021530678530100236,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 304081.37299999985,
#          'percentage': 0.02241826514438013,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 311136.4359999998,
#          'percentage': 0.023444481424178445,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 329761.67300000007,
#          'percentage': 0.026382357437283805,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 353125.3229999997,
#          'percentage': 0.026597838381645922,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 319664.4180000003,
#          'percentage': 0.026255315633395004,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 294842.1870000004,
#          'percentage': 0.026141220694821103,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 276226.0590000001,
#          'percentage': 0.02335403737443948,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 305254.1179999998,
#          'percentage': 0.0295987747610667,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 349601.97299999994,
#          'percentage': 0.03237749624174127,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 401.4,
#          'percentage': 0.06374583484333993,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 3696212.9059999995}},
#      {'type': 'Renewable waste',
#       'id': '10295',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Renewable waste',
#        'description': '10295',
#        'color': '#a0a0a0',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:40.000+01:00',
#        'values': [{'value': 69243.12599999993,
#          'percentage': 0.005756407676145312,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 59035.88650000006,
#          'percentage': 0.004526483348544241,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 53783.33,
#          'percentage': 0.003734038440916111,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 50281.08249999995,
#          'percentage': 0.003706950636635843,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 49402.42050000002,
#          'percentage': 0.0037225281121421074,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 70479.63349999997,
#          'percentage': 0.005638674944027714,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 78697.00150000001,
#          'percentage': 0.005927555999763712,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 78251.68099999998,
#          'percentage': 0.0064271231573191125,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 74356.19800000003,
#          'percentage': 0.0065925497355838495,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 65960.96700000003,
#          'percentage': 0.005576790597342481,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 74711.37350000005,
#          'percentage': 0.007244341635110818,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 81463.85000000003,
#          'percentage': 0.007544566967340244,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 123.4,
#          'percentage': 0.019597000547254977,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 805789.9500000003}},
#      {'type': 'Renewable generation',
#       'id': 'Renovable',
#       'groupId': 'Renovable',
#       'attributes': {'title': 'Renewable generation',
#        'description': None,
#        'color': '#666666',
#        'type': 'Renewable generation',
#        'magnitude': None,
#        'composite': True,
#        'last-update': '2024-12-10T12:17:35.000+01:00',
#        'values': [{'value': 12028878.06,
#          'percentage': 1,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 13042329.3215,
#          'percentage': 1,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 14403528.74,
#          'percentage': 1,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 13564001.096500002,
#          'percentage': 1,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 13271201.455500005,
#          'percentage': 1,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 12499325.497499995,
#          'percentage': 1,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 13276466.979499996,
#          'percentage': 1,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 12175226.627000002,
#          'percentage': 1,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 11278822.456000008,
#          'percentage': 1,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 11827764.705999997,
#          'percentage': 1,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 10313066.0125,
#          'percentage': 1,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 10797683.996000003,
#          'percentage': 1,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 6296.882,
#          'percentage': 1,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 148484591.82999998}}]}},
#   {'type': 'Non-renewable',
#    'id': 'Non-renewable',
#    'attributes': {'title': 'Non-renewable',
#     'last-update': '2025-01-03T08:33:38.000+01:00',
#     'description': None,
#     'magnitude': None,
#     'content': [{'type': 'Pumped storage',
#       'id': '1445',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Pumped storage',
#        'description': '1445',
#        'color': '#007cf9',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:38.000+01:00',
#        'values': [{'value': 451576.101,
#          'percentage': 0.0395520064932851,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 539412.305,
#          'percentage': 0.05907927215640247,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 576583.138,
#          'percentage': 0.071716815803236,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 476805.781,
#          'percentage': 0.0633927745071462,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 633361.065,
#          'percentage': 0.07847908124404128,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 503334.253,
#          'percentage': 0.055866851238943964,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 456982.729,
#          'percentage': 0.04175858837204267,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 426903.98,
#          'percentage': 0.038200268844918735,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 423292.105,
#          'percentage': 0.04096900825269225,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 341078.39,
#          'percentage': 0.03489888883981635,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 269729.913,
#          'percentage': 0.026367731203548635,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 256340.4,
#          'percentage': 0.021603566067055567,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 104.8,
#          'percentage': 0.005774265662723158,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 5355504.96}},
#      {'type': 'Nuclear',
#       'id': '1446',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Nuclear',
#        'description': '1446',
#        'color': '#464394',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:38.000+01:00',
#        'values': [{'value': 5160797.953,
#          'percentage': 0.45201664502521677,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 4509472.993,
#          'percentage': 0.49390119536741706,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 3470632.179,
#          'percentage': 0.4316856881481098,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 3501399.784,
#          'percentage': 0.4655217193486218,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 3508441.851,
#          'percentage': 0.43472721687529625,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 4324513.927,
#          'percentage': 0.47999311551016255,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 5046926.675,
#          'percentage': 0.46118271039780795,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 5095174.285,
#          'percentage': 0.4559269452084204,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 4986032.47,
#          'percentage': 0.48258118447926523,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 4613877.232,
#          'percentage': 0.4720885091551169,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 3602336.944,
#          'percentage': 0.352150234979703,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 4235663.2,
#          'percentage': 0.35696842861677675,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 7089.9,
#          'percentage': 0.3906389897150851,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 52062359.393}},
#      {'type': 'Combined cycle',
#       'id': '1454',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Combined cycle',
#        'description': '1454',
#        'color': '#ffcc66',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:39.000+01:00',
#        'values': [{'value': 3350972.015,
#          'percentage': 0.2935001799311267,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 2083469.6,
#          'percentage': 0.22819254656786328,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 2177767.349,
#          'percentage': 0.2708760099580549,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 2015743.203,
#          'percentage': 0.2679991716209742,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 1954241.05,
#          'percentage': 0.2421478846878448,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 2074499.502,
#          'percentage': 0.23025604632056967,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 3201363.716,
#          'percentage': 0.2925371598576035,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 3453686.653,
#          'percentage': 0.30904316856148206,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 2839166.674,
#          'percentage': 0.274793320083007,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 2806096.847,
#          'percentage': 0.2871177559422986,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 4079613.834,
#          'percentage': 0.3988069391072338,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 5126930.838,
#          'percentage': 0.4320816737430291,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 8414.393,
#          'percentage': 0.4636158451579972,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 35171965.674}},
#      {'type': 'Coal',
#       'id': '10289',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Coal',
#        'description': '10289',
#        'color': '#993300',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:36.000+01:00',
#        'values': [{'value': 268145.83499999996,
#          'percentage': 0.02348597674584943,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 206174.85499999975,
#          'percentage': 0.022581354295119017,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 208948.8519999998,
#          'percentage': 0.02598956740767817,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 214603.58099999995,
#          'percentage': 0.0285321968836596,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 231861.4950000001,
#          'percentage': 0.028729705864489606,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 213046.8280000002,
#          'percentage': 0.023646821919756957,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 206383.67499999993,
#          'percentage': 0.018859117389170368,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 218959.2079999998,
#          'percentage': 0.019592931908647172,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 293984.80299999996,
#          'percentage': 0.028453792730845057,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 304009.2790000003,
#          'percentage': 0.031106004792897386,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 282089.3749999996,
#          'percentage': 0.02757594340445667,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 307674.1,
#          'percentage': 0.025929809528548214,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 427.5,
#          'percentage': 0.02355437567570754,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 2956309.3859999995}},
#      {'type': 'Diesel engines',
#       'id': '10344',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Diesel engines',
#        'description': '10344',
#        'color': '#8DA69F',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:36.000+01:00',
#        'values': [{'value': 203304.8420000001,
#          'percentage': 0.017806775896894295,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 181440.60900000008,
#          'percentage': 0.019872329607561346,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 191236.2119999999,
#          'percentage': 0.023786426079828546,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 190286.7160000002,
#          'percentage': 0.025299195940523593,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 183908.5630000002,
#          'percentage': 0.022787910174351975,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 194546.7870000001,
#          'percentage': 0.021593436853469067,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 244281.056,
#          'percentage': 0.02232213914717093,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 251557.2529999999,
#          'percentage': 0.022509873753084327,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 224862.62100000016,
#          'percentage': 0.02176369099884586,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 213808.2880000001,
#          'percentage': 0.021876706043861185,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 196143.781,
#          'percentage': 0.019174241511195348,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 201285.51399999988,
#          'percentage': 0.01696371270404601,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 244.911,
#          'percentage': 0.01349409520728236,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 2476907.153000001}},
#      {'type': 'Gas turbine',
#       'id': '1450',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Gas turbine',
#        'description': '1450',
#        'color': '#00ccff',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:38.000+01:00',
#        'values': [{'value': 53192.395,
#          'percentage': 0.004658939983259622,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 47101.414,
#          'percentage': 0.005158794545217846,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 47807.375,
#          'percentage': 0.005946397806227953,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 44539.891,
#          'percentage': 0.005921713576572325,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 42650.688,
#          'percentage': 0.005284800398436644,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 70240.126,
#          'percentage': 0.007796200331803527,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 68613.518,
#          'percentage': 0.00626982919286593,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 73169.226,
#          'percentage': 0.00654733672048365,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 60791.802,
#          'percentage': 0.005883832484506257,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 56695.983,
#          'percentage': 0.005801091087538901,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 51416.17,
#          'percentage': 0.0050262417504875,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 36701.198,
#          'percentage': 0.003093062021176091,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 26.95,
#          'percentage': 0.001484889881778522,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 652946.736}},
#      {'type': 'Steam turbine',
#       'id': '1451',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Steam turbine',
#        'description': '1451',
#        'color': '#AF8E00',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:38.000+01:00',
#        'values': [{'value': 118364.47,
#          'percentage': 0.010367139172438731,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 100186.932,
#          'percentage': 0.010972999628072976,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 116048.898,
#          'percentage': 0.014434444737498588,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 98285.223,
#          'percentage': 0.013067318449781085,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 106538.14,
#          'percentage': 0.013201025144558018,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 79128.83,
#          'percentage': 0.008782789067052996,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 105680.647,
#          'percentage': 0.009656983419529069,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 101502.727,
#          'percentage': 0.009082678170141191,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 73604.264,
#          'percentage': 0.0071239072584388,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 85936.984,
#          'percentage': 0.008793008703497973,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 88402.636,
#          'percentage': 0.008641892616979237,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 61784.203,
#          'percentage': 0.005206979123894918,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 58.68,
#          'percentage': 0.003233147987486593,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 1135522.6339999996}},
#      {'type': 'Fuel + Gas',
#       'id': '10290',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Fuel + Gas',
#        'description': '10290',
#        'color': '#ba0f16',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-11-12T00:14:33.000+01:00',
#        'values': [{'value': 0.001,
#          'percentage': 1.24382436940492e-10,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 0,
#          'percentage': 0,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': -0.001,
#          'percentage': 9.137892030060213e-11,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 0,
#          'percentage': 0,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 0,
#          'percentage': 0,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': -0.001,
#          'percentage': 1.0231926109366339e-10,
#          'datetime': '2024-10-01T00:00:00.000+02:00'}],
#        'total': -0.001}},
#      {'type': 'Cogeneration',
#       'id': '10293',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Cogeneration',
#        'description': '10293',
#        'color': '#cfa2ca',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:39.000+01:00',
#        'values': [{'value': 1700349.2380000001,
#          'percentage': 0.14892777530365445,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 1372900.3590000025,
#          'percentage': 0.15036726674780582,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 1174049.5760000008,
#          'percentage': 0.14603114735183145,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 908237.194000001,
#          'percentage': 0.1207528891900018,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 1328960.4290000007,
#          'percentage': 0.16467004247823006,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 1440780.2929999998,
#          'percentage': 0.15991730707235036,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 1475815.561000001,
#          'percentage': 0.13485843252700752,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 1397733.9479999999,
#          'percentage': 0.12507218271253798,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 1296672.4129999983,
#          'percentage': 0.12550052826814548,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 1221237.6950000003,
#          'percentage': 0.12495613857212869,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 1534308.6020000011,
#          'percentage': 0.14998795035695026,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 1515853.2399999998,
#          'percentage': 0.1277513634928409,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 1631.66,
#          'percentage': 0.08990112892403501,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 16368530.208000006}},
#      {'type': 'Non-renewable waste',
#       'id': '10294',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Non-renewable waste',
#        'description': '10294',
#        'color': '#666666',
#        'type': 'distinct',
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2024-12-10T12:17:40.000+01:00',
#        'values': [{'value': 110571.29299999995,
#          'percentage': 0.009684561448274976,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 90154.92149999994,
#          'percentage': 0.009874241084540323,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 76646.69399999999,
#          'percentage': 0.009533502583152184,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 71551.7375,
#          'percentage': 0.009513020482719393,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 80481.16049999997,
#          'percentage': 0.009972333132751417,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 109442.68950000008,
#          'percentage': 0.012147431685890924,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 137395.35949999993,
#          'percentage': 0.012555039605423073,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 156730.928,
#          'percentage': 0.014024614120284384,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 133600.45699999994,
#          'percentage': 0.01293073544425416,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 130590.23900000006,
#          'percentage': 0.013361896760524909,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 125504.50750000023,
#          'percentage': 0.012268825069445523,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 123419.45000000003,
#          'percentage': 0.010401404702632367,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 150.7,
#          'percentage': 0.008303261787904389,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 1346240.137}},
#      {'type': 'Non-renewable generation',
#       'id': 'Non-renewable',
#       'groupId': 'Non-renewable',
#       'attributes': {'title': 'Non-renewable generation',
#        'description': None,
#        'color': '#666666',
#        'type': 'Non-renewable generation',
#        'magnitude': None,
#        'composite': True,
#        'last-update': '2025-01-03T08:33:38.000+01:00',
#        'values': [{'value': 11417274.141999999,
#          'percentage': 1,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 9130313.9885,
#          'percentage': 1,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 8039720.274,
#          'percentage': 1,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 7521453.110500001,
#          'percentage': 1,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 8070444.441500001,
#          'percentage': 1,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 9009533.2355,
#          'percentage': 1,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 10943442.935500002,
#          'percentage': 1,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 11175418.208,
#          'percentage': 1,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 10332007.608999997,
#          'percentage': 1,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 9773330.935999999,
#          'percentage': 1,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 10229545.762500001,
#          'percentage': 1,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 11865652.143000001,
#          'percentage': 1,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 18149.494000000002,
#          'percentage': 1,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 117526286.28000002}}]}},
#   {'type': 'Demand',
#    'id': 'Demand at busbars',
#    'attributes': {'title': 'Demand',
#     'last-update': '2025-01-03T08:33:41.000+01:00',
#     'description': 'Corrected demand: After factoring in the influence of seasonal and working patterns',
#     'magnitude': None,
#     'content': [{'type': 'Pumped storage consumption',
#       'id': '1472',
#       'groupId': 'Demand at busbars',
#       'attributes': {'title': 'Pumped storage consumption',
#        'description': '1472',
#        'color': '#4f81bd',
#        'type': None,
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:41.000+01:00',
#        'values': [{'value': -735934.137,
#          'percentage': 0.029829765120074174,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': -864337.553,
#          'percentage': 0.03577911351759763,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': -1060911.256,
#          'percentage': 0.04359211945773622,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': -713743.775,
#          'percentage': 0.03104569018471139,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': -968123.122,
#          'percentage': 0.04154580478321277,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': -791003.594,
#          'percentage': 0.033612844554811054,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': -645313.386,
#          'percentage': 0.02498495633670124,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': -661430.845,
#          'percentage': 0.02709466362262291,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': -702644.035,
#          'percentage': 0.029969555621969575,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': -528143.049,
#          'percentage': 0.022944278221646738,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': -453244.656,
#          'percentage': 0.021193937255757266,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': -592917.9,
#          'percentage': 0.024856341851161753,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': -316.5,
#          'percentage': 0.012656215285381061,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': -8718063.808}},
#      {'type': 'Cross-border exchange balance',
#       'id': '1474',
#       'groupId': 'Demand at busbars',
#       'attributes': {'title': 'Cross-border exchange balance',
#        'description': '1474',
#        'color': '#00608a',
#        'type': None,
#        'magnitude': None,
#        'composite': False,
#        'last-update': '2025-01-03T08:33:41.000+01:00',
#        'values': [{'value': -489047.813,
#          'percentage': 0.019822672520320876,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': -1120620.263,
#          'percentage': 0.046387894938538114,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': -833065.568,
#          'percentage': 0.03423009563806803,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': -1190910.17,
#          'percentage': 0.0518009816276744,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': -992779.266,
#          'percentage': 0.042603892666925956,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': -1232915.231,
#          'percentage': 0.05239140292561295,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': -962854.095,
#          'percentage': 0.03727935611456382,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': -399773.613,
#          'percentage': 0.016376211740526902,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': -1131786.279,
#          'percentage': 0.048273564068145085,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': -889269.187,
#          'percentage': 0.038632790262218525,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': -389724.291,
#          'percentage': 0.01822369455691605,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': -597533.6,
#          'percentage': 0.02504984151963593,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 244.6,
#          'percentage': 0.009781075067311872,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': -10230034.775999999}},
#      {'type': 'Demand at busbars',
#       'id': 'Demand at busbars',
#       'groupId': 'Demand at busbars',
#       'attributes': {'title': 'Demand at busbars',
#        'description': 'Corrected demand: After factoring in the influence of seasonal and working patterns',
#        'color': '#666666',
#        'type': 'Demand at busbars',
#        'magnitude': None,
#        'composite': True,
#        'last-update': '2025-01-03T08:33:41.000+01:00',
#        'values': [{'value': 22221170.25199999,
#          'percentage': 1,
#          'datetime': '2024-01-01T00:00:00.000+01:00'},
#         {'value': 20187685.494000044,
#          'percentage': 1,
#          'datetime': '2024-02-01T00:00:00.000+01:00'},
#         {'value': 20549272.189999986,
#          'percentage': 1,
#          'datetime': '2024-03-01T00:00:00.000+01:00'},
#         {'value': 19180800.26200001,
#          'percentage': 1,
#          'datetime': '2024-04-01T00:00:00.000+02:00'},
#         {'value': 19380743.50900001,
#          'percentage': 1,
#          'datetime': '2024-05-01T00:00:00.000+02:00'},
#         {'value': 19484939.908,
#          'percentage': 1,
#          'datetime': '2024-06-01T00:00:00.000+02:00'},
#         {'value': 22611742.433999997,
#          'percentage': 1,
#          'datetime': '2024-07-01T00:00:00.000+02:00'},
#         {'value': 22289440.377,
#          'percentage': 1,
#          'datetime': '2024-08-01T00:00:00.000+02:00'},
#         {'value': 19776399.751000002,
#          'percentage': 1,
#          'datetime': '2024-09-01T00:00:00.000+02:00'},
#         {'value': 20183683.40600003,
#          'percentage': 1,
#          'datetime': '2024-10-01T00:00:00.000+02:00'},
#         {'value': 19699642.82799999,
#          'percentage': 1,
#          'datetime': '2024-11-01T00:00:00.000+01:00'},
#         {'value': 21472884.638999976,
#          'percentage': 1,
#          'datetime': '2024-12-01T00:00:00.000+01:00'},
#         {'value': 24374.476,
#          'percentage': 1,
#          'datetime': '2025-01-01T00:00:00.000+01:00'}],
#        'total': 247062779.52600002}}]}}]}

# %% [markdown]
# Change parameters accordingly.

# %% [markdown]
# When your connection is succesfully established. Access the data by means of a json object

# %%
data_json = response.json()

# Demand at busbars is the sum of the (non-) renewable generation minus the pumped hydrogen consumption and the exchange of energy
demand = None
for item in data_json['included']:
    if item['id'] == 'Demand at busbars':
        demand = item
        break
total_demand = demand['attributes']['content'][-1]['attributes']['values']

# %% [markdown]
# Store the data in local python structures

# %%
times = []
demand_values = []
for data_point in total_demand:
    demand_values.append(data_point['value'])
    times.append(data_point['datetime'])
print(demand_values)
# Out:
# [22221170.25199999, 20187685.494000044, 20549272.189999986, 19180800.26200001, 19380743.50900001, 19484939.908, 22611742.433999997, 22289440.377, 19776399.751000002, 20183683.40600003, 19699642.82799999, 21472884.638999976, 24374.476]

# %% [markdown]
# Print the data for better visualization and analysis

# %%
times = [datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%f%z") for date_str in times]
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
plt.style.use('ggplot')

plt.figure(figsize=(20,10))
plt.plot(times, demand_values, 'b', linewidth=1.5, marker='.')
plt.title(f"Balance", fontsize=20)
plt.xlabel('Month', fontsize=20 )
plt.ylabel('Balance [MWh]', fontsize=20)
plt.show()

# %% [markdown]
# # Part III: Exercize - REE API

# %% [markdown]
# Going back to the Part 1 of the lab, take the most updated prices for the spot market and the PVPC and compare them in a chart. Draw some conclusions.

# %%
endpoint = 'https://apidatos.ree.es'

get_archives = '/en/datos/mercados/precios-mercados-tiempo-real'

headers = {'Accept': 'application/json',
           'Content-Type': 'application/json',
           'Host': 'apidatos.ree.es'}

# %%
end_date = datetime.now()
start_date = end_date - timedelta(hours=24)             

end_date = end_date.strftime('%Y-%m-%dT%H:%M')
start_date = start_date.strftime('%Y-%m-%dT%H:%M')
start_date
# Out:
# '2025-01-02T15:01'

# %%
end_date
# Out:
# '2025-01-03T15:01'

# %%
params = {'start_date': start_date, 'end_date': end_date, 'time_trunc':'hour'}
response = requests.get(endpoint+get_archives, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %%
data_json = response.json()
data_json
# Out:
# {'data': {'type': 'Precios mercado peninsular en tiempo real',
#   'id': 'mer13',
#   'attributes': {'title': 'Precios mercado peninsular en tiempo real',
#    'last-update': '2025-01-03T10:45:22.000+01:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'PVPC',
#    'id': '1001',
#    'groupId': None,
#    'attributes': {'title': 'PVPC',
#     'description': None,
#     'color': '#ffcf09',
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2025-01-03T10:45:22.000+01:00',
#     'values': [{'value': 186.57,
#       'percentage': 0.5721777532431687,
#       'datetime': '2025-01-02T16:00:00.000+01:00'},
#      {'value': 199.7,
#       'percentage': 0.5655621636930047,
#       'datetime': '2025-01-02T17:00:00.000+01:00'},
#      {'value': 274.4,
#       'percentage': 0.632870519857927,
#       'datetime': '2025-01-02T18:00:00.000+01:00'},
#      {'value': 277.24,
#       'percentage': 0.6326358304999657,
#       'datetime': '2025-01-02T19:00:00.000+01:00'},
#      {'value': 278.06,
#       'percentage': 0.6331633117770289,
#       'datetime': '2025-01-02T20:00:00.000+01:00'},
#      {'value': 274.91,
#       'percentage': 0.6352041405762611,
#       'datetime': '2025-01-02T21:00:00.000+01:00'},
#      {'value': 203.8,
#       'percentage': 0.5720862339995508,
#       'datetime': '2025-01-02T22:00:00.000+01:00'},
#      {'value': 190.99,
#       'percentage': 0.5770264962687695,
#       'datetime': '2025-01-02T23:00:00.000+01:00'},
#      {'value': 154.55,
#       'percentage': 0.5598217843300612,
#       'datetime': '2025-01-03T00:00:00.000+01:00'},
#      {'value': 141.34,
#       'percentage': 0.5739928525016245,
#       'datetime': '2025-01-03T01:00:00.000+01:00'},
#      {'value': 134.85,
#       'percentage': 0.5894051313431531,
#       'datetime': '2025-01-03T02:00:00.000+01:00'},
#      {'value': 131.54,
#       'percentage': 0.5908192597915918,
#       'datetime': '2025-01-03T03:00:00.000+01:00'},
#      {'value': 126.83,
#       'percentage': 0.5891123600724604,
#       'datetime': '2025-01-03T04:00:00.000+01:00'},
#      {'value': 129.22,
#       'percentage': 0.5834650291235833,
#       'datetime': '2025-01-03T05:00:00.000+01:00'},
#      {'value': 137.41,
#       'percentage': 0.5784466428120395,
#       'datetime': '2025-01-03T06:00:00.000+01:00'},
#      {'value': 156.63,
#       'percentage': 0.554187453561193,
#       'datetime': '2025-01-03T07:00:00.000+01:00'},
#      {'value': 193.6,
#       'percentage': 0.5782556750298686,
#       'datetime': '2025-01-03T08:00:00.000+01:00'},
#      {'value': 190.66,
#       'percentage': 0.5801131868800584,
#       'datetime': '2025-01-03T09:00:00.000+01:00'},
#      {'value': 251.38,
#       'percentage': 0.6582351400890286,
#       'datetime': '2025-01-03T10:00:00.000+01:00'},
#      {'value': 240.31,
#       'percentage': 0.6610822260735606,
#       'datetime': '2025-01-03T11:00:00.000+01:00'},
#      {'value': 227.16,
#       'percentage': 0.6668036516276749,
#       'datetime': '2025-01-03T12:00:00.000+01:00'},
#      {'value': 218.51,
#       'percentage': 0.6700499831345251,
#       'datetime': '2025-01-03T13:00:00.000+01:00'},
#      {'value': 152.51,
#       'percentage': 0.5902318201168776,
#       'datetime': '2025-01-03T14:00:00.000+01:00'},
#      {'value': 158.29,
#       'percentage': 0.5895124948791479,
#       'datetime': '2025-01-03T15:00:00.000+01:00'}]}},
#   {'type': 'Spot market price',
#    'id': '600',
#    'groupId': None,
#    'attributes': {'title': 'Spot market price',
#     'description': None,
#     'color': '#df4a32',
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2025-01-02T14:10:22.000+01:00',
#     'values': [{'value': 139.5,
#       'percentage': 0.42782224675683134,
#       'datetime': '2025-01-02T16:00:00.000+01:00'},
#      {'value': 153.4,
#       'percentage': 0.4344378363069952,
#       'datetime': '2025-01-02T17:00:00.000+01:00'},
#      {'value': 159.18,
#       'percentage': 0.36712948014207303,
#       'datetime': '2025-01-02T18:00:00.000+01:00'},
#      {'value': 160.99,
#       'percentage': 0.36736416950003425,
#       'datetime': '2025-01-02T19:00:00.000+01:00'},
#      {'value': 161.1,
#       'percentage': 0.36683668822297116,
#       'datetime': '2025-01-02T20:00:00.000+01:00'},
#      {'value': 157.88,
#       'percentage': 0.364795859423739,
#       'datetime': '2025-01-02T21:00:00.000+01:00'},
#      {'value': 152.44,
#       'percentage': 0.4279137660004491,
#       'datetime': '2025-01-02T22:00:00.000+01:00'},
#      {'value': 140,
#       'percentage': 0.42297350373123055,
#       'datetime': '2025-01-02T23:00:00.000+01:00'},
#      {'value': 121.52,
#       'percentage': 0.44017821566993875,
#       'datetime': '2025-01-03T00:00:00.000+01:00'},
#      {'value': 104.9,
#       'percentage': 0.4260071474983756,
#       'datetime': '2025-01-03T01:00:00.000+01:00'},
#      {'value': 93.94,
#       'percentage': 0.4105948686568469,
#       'datetime': '2025-01-03T02:00:00.000+01:00'},
#      {'value': 91.1,
#       'percentage': 0.40918074020840817,
#       'datetime': '2025-01-03T03:00:00.000+01:00'},
#      {'value': 88.46,
#       'percentage': 0.41088763992753957,
#       'datetime': '2025-01-03T04:00:00.000+01:00'},
#      {'value': 92.25,
#       'percentage': 0.41653497087641667,
#       'datetime': '2025-01-03T05:00:00.000+01:00'},
#      {'value': 100.14,
#       'percentage': 0.4215533571879604,
#       'datetime': '2025-01-03T06:00:00.000+01:00'},
#      {'value': 126,
#       'percentage': 0.4458125464388069,
#       'datetime': '2025-01-03T07:00:00.000+01:00'},
#      {'value': 141.2,
#       'percentage': 0.4217443249701314,
#       'datetime': '2025-01-03T08:00:00.000+01:00'},
#      {'value': 138,
#       'percentage': 0.41988681311994164,
#       'datetime': '2025-01-03T09:00:00.000+01:00'},
#      {'value': 130.52,
#       'percentage': 0.3417648599109715,
#       'datetime': '2025-01-03T10:00:00.000+01:00'},
#      {'value': 123.2,
#       'percentage': 0.33891777392643946,
#       'datetime': '2025-01-03T11:00:00.000+01:00'},
#      {'value': 113.51,
#       'percentage': 0.33319634837232515,
#       'datetime': '2025-01-03T12:00:00.000+01:00'},
#      {'value': 107.6,
#       'percentage': 0.3299500168654748,
#       'datetime': '2025-01-03T13:00:00.000+01:00'},
#      {'value': 105.88,
#       'percentage': 0.4097681798831224,
#       'datetime': '2025-01-03T14:00:00.000+01:00'},
#      {'value': 110.22,
#       'percentage': 0.41048750512085214,
#       'datetime': '2025-01-03T15:00:00.000+01:00'}]}}]}

# %%
spot_price = data_json["included"][1]["attributes"]["values"]
pvpc = data_json["included"][0]["attributes"]["values"]

times = []
spot_price_values = []
pvpc_values = []
for data_point in spot_price:
    spot_price_values.append(data_point['value'])
    times.append(data_point['datetime'])

for data_point in pvpc:
    pvpc_values.append(data_point['value'])


times = [datetime.strptime(time_str, "%Y-%m-%dT%H:%M:%S.%f%z") for time_str in times]
print(f"The PVPC price is {pvpc_values[-1]} €/MWh")
print(f"The spot price is {spot_price_values[-1]} €/MWh")
# Out:
# The PVPC price is 158.29 €/MWh
# The spot price is 110.22 €/MWh

# %%
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
plt.style.use('ggplot')

plt.figure(figsize=(20,10))
plt.plot(times, spot_price_values, 'b', linewidth=1.5, marker='.', label='Spot Price')
plt.plot(times, pvpc_values, 'r', linewidth=1.5, marker='.', label='PVPC')
plt.title(f"Spot Price vs PVPC", fontsize=20)
plt.xlabel('Hour', fontsize=20 )
plt.ylabel('Price [€/MWh]', fontsize=20)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# It can be seen that the price the customer should pay (pvpc - price of energy on regulated market) is higher than the spot price (price of energy on free market)

# %% [markdown]
# # Part IV: CO2 Signal API

# %% [markdown]
# This is a free to use API from the famous **electricitymap.org**.
#
# You can use our API to get access to information about how much carbon is emitted when producing electricity in a country.
# API documentation is available at https://docs.co2signal.com/#introduction
#
# CO2 Signal uses API keys to allow access to the API. You can get an API key by making a request in their website.
# CO2 Signal expects the API key to be included as a header in all requests to the server

# %% [markdown]
# ### Get latest by country code

# %%
my_api_token = 'QE4sZ9U7d2FcBeTQuENPlZsQ9PYeVeFG'

endpoint = 'https://api.co2signal.com'
get_archive = '/v1/latest'
headers = {'auth-token': my_api_token}
params = {'countryCode':'IT'} 

# NB: this parameters are asking data for country Italy, but you can change it, based on the info given in the API documentation

# %%
response = requests.get(endpoint+get_archive, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %%
# extract the data in json format
json_data = response.json()
json_data
# Out:
# {'_disclaimer': "This data is the exclusive property of Electricity Maps and/or related parties. If you're in doubt about your rights to use this data, please contact api@co2signal.com",
#  'status': 'ok',
#  'countryCode': 'IT',
#  'data': {'datetime': '2025-01-03T14:00:00.000Z',
#   'carbonIntensity': 402,
#   'fossilFuelPercentage': 63.029999999999994},
#  'units': {'carbonIntensity': 'gCO2eq/kWh'}}

# %% [markdown]
# Looking both at the docs and at the json structure we can see we have 2 information available **carbon intensity** and **fossil fuel percentage** for the desired country at the latest time available.

# %%
co2_intensity = json_data['data']['carbonIntensity']
ff_perc = json_data['data']['fossilFuelPercentage']
time_str = json_data['data']['datetime']
# from string to datetime
time = datetime.strptime(time_str[:16], '%Y-%m-%dT%H:%M') 

print(f"Details of energy production in country {params['countryCode']} at {time}")
print(f"Carbon Intensity: {co2_intensity}")
print(f"Fossil Fuel Percentage: {ff_perc}")
# Out:
# Details of energy production in country IT at 2025-01-03 14:00:00
# Carbon Intensity: 402
# Fossil Fuel Percentage: 63.029999999999994

# %% [markdown]
# # Part V: WeatherAPI.com

# %% [markdown]
# WeatherAPI.com is a powerful fully managed **free weather and geolocation API provider** that provides extensive APIs that range from the weather forecast, historical weather, future weather, weather alerts, air quality data, IP lookup, and astronomy through to sports, time zone, and geolocation.
#
# The API can be found accessed in the popular API market place **RapidAPI** (https://rapidapi.com/weatherapi/api/weatherapi-com)
#
# It is required to sign up with an account in RapidAPI to use the free API. When you did that you need to subscribe to a pricing plan for the API (the free one, of course). Take a look at the limited functionalities, you can access only a few endpoints. As you can see all of them allow for **GET** methods.
#
# Once the subscription is active you can generate in an authomatic way the code for the request through the interface (very useful) and copypaste it to use it right away.
#
# One of the endpoints available with the free subscription is the current weather. Let's check this out

# %%
import requests

# chose the endpoint
url = "https://weatherapi-com.p.rapidapi.com/current.json"

# define the headers with the authorization token
headers = {"X-RapidAPI-Key": "6a425b2a7bmshc1f059e65b98fb7p1cdd78jsn184965114ca2",
           "X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"}

# define parameters as specified in the API documentation
querystring = {"q":"Barcelona","dt":"2022-12-25"}

#create the get request
response = requests.request("GET", url, headers=headers, params=querystring)
data_json = response.text
print(response.text)
# Out:
# {"location":{"name":"Barcelona","region":"Catalonia","country":"Spain","lat":41.3833,"lon":2.1833,"tz_id":"Europe/Madrid","localtime_epoch":1735912802,"localtime":"2025-01-03 15:00"},"current":{"last_updated_epoch":1735911900,"last_updated":"2025-01-03 14:45","temp_c":11.3,"temp_f":52.3,"is_day":1,"condition":{"text":"Sunny","icon":"//cdn.weatherapi.com/weather/64x64/day/113.png","code":1000},"wind_mph":8.1,"wind_kph":13.0,"wind_degree":298,"wind_dir":"WNW","pressure_mb":1019.0,"pressure_in":30.09,"precip_mm":0.0,"precip_in":0.0,"humidity":58,"cloud":0,"feelslike_c":9.8,"feelslike_f":49.6,"windchill_c":12.0,"windchill_f":53.7,"heatindex_c":13.2,"heatindex_f":55.7,"dewpoint_c":1.4,"dewpoint_f":34.5,"vis_km":10.0,"vis_miles":6.0,"uv":1.3,"gust_mph":9.8,"gust_kph":15.7}}

# %%
import json
data = json.loads(data_json)
print(data)
# Out:
# {'location': {'name': 'Barcelona', 'region': 'Catalonia', 'country': 'Spain', 'lat': 41.3833, 'lon': 2.1833, 'tz_id': 'Europe/Madrid', 'localtime_epoch': 1735912802, 'localtime': '2025-01-03 15:00'}, 'current': {'last_updated_epoch': 1735911900, 'last_updated': '2025-01-03 14:45', 'temp_c': 11.3, 'temp_f': 52.3, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 298, 'wind_dir': 'WNW', 'pressure_mb': 1019.0, 'pressure_in': 30.09, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 58, 'cloud': 0, 'feelslike_c': 9.8, 'feelslike_f': 49.6, 'windchill_c': 12.0, 'windchill_f': 53.7, 'heatindex_c': 13.2, 'heatindex_f': 55.7, 'dewpoint_c': 1.4, 'dewpoint_f': 34.5, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.3, 'gust_mph': 9.8, 'gust_kph': 15.7}}

# %% [markdown]
# You can now go on with the data extraction and post-processing of streaming data as you like

# %%
# Extract location details
location_name = data['location']['name']
country = data['location']['country']
local_time = data['location']['localtime']

# Extract current weather details
temp_c = data['current']['temp_c']
feelslike_c = data['current']['feelslike_c']
humidity = data['current']['humidity']
wind_kph = data['current']['wind_kph']
condition_text = data['current']['condition']['text']

print(f"Location: {location_name}, {country}")
print(f"Local Time: {local_time}")
print(f"Temperature (°C): {temp_c}")
print(f"Feels Like (°C): {feelslike_c}")
print(f"Humidity: {humidity}%")
print(f"Wind (kph): {wind_kph}")
print(f"Condition: {condition_text}")
# Out:
# Location: Barcelona, Spain
# Local Time: 2025-01-03 15:00
# Temperature (°C): 11.3
# Feels Like (°C): 9.8
# Humidity: 58%
# Wind (kph): 13.0
# Condition: Sunny

# %%
temp_diff = temp_c - feelslike_c
print(f"Difference between actual and feels-like: {temp_diff:.2f}°C")
# Out:
# Difference between actual and feels-like: 1.50°C

# %% [markdown]
# # Part VI: Electricity Map free API

# %% [markdown]
# Go to the website https://api-portal.electricitymaps.com/ and sign up with your account of preference. Confirm your email and validate your account, then go to the Getting Started section and choose the product plan option **Free Tier**. Subscrive to the free plan.
#
# In your personal account on the API portal you need to access the *Product Catalog* and enter the *Personal Free Tier* product. Once inside, you will find yourself into the actual API Client of the free tier product. Here you can find the documentation, specyifing the endpoints and your personal API key generator (Blobr API Keys). You can also keep en eye on your requests history.

# %% [markdown]
# You can also check if the API service is UP and running by making a simple GET request on the dedicated endpoint. This instruction is available in the API documentation under "Health" route.

# %%
# check if API is up
health_endpoint = 'https://api.electricitymap.org/health'      
# NB: this is an endpoint available withing the paid API service but you can use it without token to test the connection 

# make a small get request (no token required)
response = requests.get(health_endpoint)
response

status = response.status_code

# check the status code
if status < 200:
    print('informational')
    # If the status code is 200, treat the information.
elif status >= 200 and status < 300:
    print('Connection is established. API is UP!')
    #okBehavior(response) # runs the function to get list of archives
elif status >= 300 and status < 400:
    print('redirection')
elif status >= 400 and status < 500:
    print('client error')
else:
    print('server error')
# Out:
# Connection is established. API is UP!

# %% [markdown]
# ### Check available zones

# %% [markdown]
# Each token (you can use the primary token) has some zones that can be accessed, for which data are available. An endpoint is available to return all zones available if no auth-token is provided.

# %%
#my_token = 'tYmqsdm22FbSg2RMasqWN1PiZOs9Mwgk' # replace with your personal API key
my_token = 'jkG9yQHIscL1a'

# %%
# check for available zones
base_prod_url = "https://api.electricitymap.org/v3/zones"

# make request (this request works with no token
response = requests.get(base_prod_url)
response
# Out:
# <Response [200]>

# %%
data_dict = response.json()

print("Country name:")
# Extract abbreviation and name of each country
for abbreviation, country_info in data_dict.items():
    country_name = country_info["zoneName"]
    print(f" {country_name}, {abbreviation}")
# Out:
# Country name:
#  Andorra, AD
#  United Arab Emirates, AE
#  Afghanistan, AF
#  Antigua and Barbuda, AG
#  Albania, AL
#  Armenia, AM
#  Angola, AO
#  Argentina, AR
#  Austria, AT
#  Australia, AU
#  Lord Howe Island, AU-LH
#  New South Wales, AU-NSW
#  Northern Territory, AU-NT
#  Queensland, AU-QLD
#  South Australia, AU-SA
#  Tasmania, AU-TAS
#  Cape Barren Island, AU-TAS-CBI
#  Flinders Island, AU-TAS-FI
#  King Island, AU-TAS-KI
#  Victoria, AU-VIC
#  Western Australia, AU-WA
#  Rottnest Island, AU-WA-RI
#  Aruba, AW
#  Åland Islands, AX
#  Azerbaijan, AZ
#  Bosnia and Herzegovina, BA
#  Barbados, BB
#  Bangladesh, BD
#  Belgium, BE
#  Burkina Faso, BF
#  Bulgaria, BG
#  Bahrain, BH
#  Burundi, BI
#  Benin, BJ
#  Brunei, BN
#  Bolivia, BO
#  Brazil, BR
#  Central Brazil, BR-CS
#  North Brazil, BR-N
#  North-East Brazil, BR-NE
#  South Brazil, BR-S
#  Bahamas, BS
#  Bhutan, BT
#  Botswana, BW
#  Belarus, BY
#  Belize, BZ
#  Alberta, CA-AB
#  British Columbia, CA-BC
#  Manitoba, CA-MB
#  New Brunswick, CA-NB
#  Labrador, CA-NL-LB
#  Newfoundland, CA-NL-NF
#  Nova Scotia, CA-NS
#  Northwest Territories, CA-NT
#  Nunavut, CA-NU
#  Ontario, CA-ON
#  Prince Edward Island, CA-PE
#  Québec, CA-QC
#  Saskatchewan, CA-SK
#  Yukon, CA-YT
#  Democratic Republic of the Congo, CD
#  Central African Republic, CF
#  Congo, CG
#  Switzerland, CH
#  Ivory Coast, CI
#  Easter Island, CL-CHP
#  Sistema Eléctrico de Aysén, CL-SEA
#  Sistema Eléctrico de Magallanes, CL-SEM
#  Sistema Eléctrico Nacional, CL-SEN
#  Cameroon, CM
#  China, CN
#  Colombia, CO
#  Costa Rica, CR
#  Cuba, CU
#  Cabo Verde, CV
#  Cyprus, CY
#  Czechia, CZ
#  Germany, DE
#  Djibouti, DJ
#  Denmark, DK
#  Bornholm, DK-BHM
#  West Denmark, DK-DK1
#  East Denmark, DK-DK2
#  Dominica, DM
#  Dominican Republic, DO
#  Algeria, DZ
#  Ecuador, EC
#  Estonia, EE
#  Egypt, EG
#  Western Sahara, EH
#  Eritrea, ER
#  Spain, ES
#  Ceuta, ES-CE
#  Fuerteventura/Lanzarote, ES-CN-FVLZ
#  Gran Canaria, ES-CN-GC
#  El Hierro, ES-CN-HI
#  Isla de la Gomera, ES-CN-IG
#  La Palma, ES-CN-LP
#  Tenerife, ES-CN-TE
#  Formentera, ES-IB-FO
#  Ibiza, ES-IB-IZ
#  Mallorca, ES-IB-MA
#  Menorca, ES-IB-ME
#  Melilla, ES-ML
#  Ethiopia, ET
#  Finland, FI
#  Fiji, FJ
#  Falkland Islands, FK
#  Micronesia, FM
#  Faroe Islands, FO
#  Main Islands, FO-MI
#  South Island, FO-SI
#  France, FR
#  Corsica, FR-COR
#  Gabon, GA
#  Great Britain, GB
#  Northern Ireland, GB-NIR
#  Orkney Islands, GB-ORK
#  Shetland Islands, GB-ZET
#  Georgia, GE
#  French Guiana, GF
#  Guernsey, GG
#  Ghana, GH
#  Gibraltar, GI
#  Greenland, GL
#  Gambia, GM
#  Guinea, GN
#  Guadeloupe, GP
#  Equatorial Guinea, GQ
#  Greece, GR
#  South Georgia and the South Sandwich Islands, GS
#  Guatemala, GT
#  Guam, GU
#  Guinea-Bissau, GW
#  Guyana, GY
#  Hong Kong, HK
#  Heard Island and McDonald Islands, HM
#  Honduras, HN
#  Croatia, HR
#  Haiti, HT
#  Hungary, HU
#  Indonesia, ID
#  Ireland, IE
#  Israel, IL
#  Isle of Man, IM
#  Mainland India, IN
#  Andaman and Nicobar Islands, IN-AN
#  Delhi, IN-DL
#  Eastern India, IN-EA
#  Himachal Pradesh, IN-HP
#  Karnataka, IN-KA
#  Maharashtra, IN-MH
#  North Eastern India, IN-NE
#  Northern India, IN-NO
#  Punjab, IN-PB
#  Southern India, IN-SO
#  Uttar Pradesh, IN-UP
#  Uttarakhand, IN-UT
#  Western India, IN-WE
#  Iraq, IQ
#  Kurdistan, IQ-KUR
#  Iran, IR
#  Iceland, IS
#  Italy, IT
#  Central North Italy, IT-CNO
#  Central South Italy, IT-CSO
#  North Italy, IT-NO
#  Sardinia, IT-SAR
#  Sicily, IT-SIC
#  South Italy, IT-SO
#  Jersey, JE
#  Jamaica, JM
#  Jordan, JO
#  Japan, JP
#  Chūbu, JP-CB
#  Chūgoku, JP-CG
#  Hokkaidō, JP-HKD
#  Hokuriku, JP-HR
#  Kansai, JP-KN
#  Kyūshū, JP-KY
#  Okinawa, JP-ON
#  Shikoku, JP-SK
#  Tōhoku, JP-TH
#  Tōkyō, JP-TK
#  Kenya, KE
#  Kyrgyzstan, KG
#  Cambodia, KH
#  Comoros, KM
#  North Korea, KP
#  South Korea, KR
#  Kuwait, KW
#  Kazakhstan, KZ
#  Laos, LA
#  Lebanon, LB
#  Saint Lucia, LC
#  Liechtenstein, LI
#  Sri Lanka, LK
#  Liberia, LR
#  Lesotho, LS
#  Lithuania, LT
#  Luxembourg, LU
#  Latvia, LV
#  Libya, LY
#  Morocco, MA
#  Moldova, MD
#  Montenegro, ME
#  Madagascar, MG
#  North Macedonia, MK
#  Mali, ML
#  Myanmar, MM
#  Mongolia, MN
#  Martinique, MQ
#  Mauritania, MR
#  Malta, MT
#  Mauritius, MU
#  Malawi, MW
#  Mexico, MX
#  Baja California, MX-BC
#  Baja California Sur, MX-BCS
#  Central, MX-CE
#  North East, MX-NE
#  North, MX-NO
#  North West, MX-NW
#  Occidental, MX-OC
#  Oriental, MX-OR
#  Peninsula, MX-PN
#  Malaysia, MY
#  Borneo, MY-EM
#  Peninsula, MY-WM
#  Mozambique, MZ
#  Namibia, NA
#  New Caledonia, NC
#  Niger, NE
#  Nigeria, NG
#  Nicaragua, NI
#  Netherlands, NL
#  Norway, NO
#  Southeast Norway, NO-NO1
#  Southwest Norway, NO-NO2
#  Middle Norway, NO-NO3
#  North Norway, NO-NO4
#  West Norway, NO-NO5
#  Nepal, NP
#  New Zealand, NZ
#  Auckland Islands, NZ-NZA
#  Chatham Islands, NZ-NZC
#  Stewart Island, NZ-NZST
#  Oman, OM
#  Panama, PA
#  Peru, PE
#  French Polynesia, PF
#  Papua New Guinea, PG
#  Philippines, PH
#  Luzon, PH-LU
#  Mindanao, PH-MI
#  Visayas, PH-VI
#  Pakistan, PK
#  Poland, PL
#  Saint Pierre and Miquelon, PM
#  Puerto Rico, PR
#  State of Palestine, PS
#  Portugal, PT
#  Azores, PT-AC
#  Madeira, PT-MA
#  Palau, PW
#  Paraguay, PY
#  Qatar, QA
#  Réunion, RE
#  Romania, RO
#  Serbia, RS
#  Russia, RU
#  Europe-Ural, RU-1
#  Siberia, RU-2
#  East, RU-AS
#  Arctic, RU-EU
#  Far East, RU-FE
#  Kaliningrad, RU-KGD
#  Rwanda, RW
#  Saudi Arabia, SA
#  Solomon Islands, SB
#  Sudan, SD
#  Sweden, SE
#  North Sweden, SE-SE1
#  North Central Sweden, SE-SE2
#  South Central Sweden, SE-SE3
#  South Sweden, SE-SE4
#  Singapore, SG
#  Slovenia, SI
#  Svalbard and Jan Mayen, SJ
#  Slovakia, SK
#  Sierra Leone, SL
#  Senegal, SN
#  Somalia, SO
#  Suriname, SR
#  South Sudan, SS
#  São Tomé and Príncipe, ST
#  El Salvador, SV
#  Syria, SY
#  Eswatini, SZ
#  Chad, TD
#  French Southern Territories, TF
#  Togo, TG
#  Thailand, TH
#  Tajikistan, TJ
#  Timor-Leste, TL
#  Turkmenistan, TM
#  Tunisia, TN
#  Tonga, TO
#  Turkey, TR
#  Trinidad and Tobago, TT
#  Taiwan, TW
#  Tanzania, TZ
#  Ukraine, UA
#  Crimea, UA-CR
#  Uganda, UG
#  Contiguous United States, US
#  Alaska, US-AK
#  Southeast Alaska Power Agency, US-AK-SEAPA
#  Balancing Authority of Northern California, US-CAL-BANC
#  CAISO, US-CAL-CISO
#  Imperial Irrigation District, US-CAL-IID
#  Los Angeles Department of Water and Power, US-CAL-LDWP
#  Turlock Irrigation District, US-CAL-TIDC
#  Duke Energy Progress East, US-CAR-CPLE
#  Duke Energy Progress West, US-CAR-CPLW
#  Duke Energy Carolinas, US-CAR-DUK
#  South Carolina Public Service Authority, US-CAR-SC
#  South Carolina Electric & Gas Company, US-CAR-SCEG
#  Alcoa Power Generating, Inc. Yadkin Division, US-CAR-YAD
#  Southwestern Power Administration, US-CENT-SPA
#  Southwest Power Pool, US-CENT-SWPP
#  Florida Municipal Power Pool, US-FLA-FMPP
#  Duke Energy Florida, US-FLA-FPC
#  Florida Power and Light Company, US-FLA-FPL
#  Gainesville Regional Utilities, US-FLA-GVL
#  City of Homestead, US-FLA-HST
#  Jacksonville Electric Authority, US-FLA-JEA
#  Seminole Electric Cooperative, US-FLA-SEC
#  City of Tallahassee, US-FLA-TAL
#  Tampa Electric Company, US-FLA-TEC
#  Hawaii, US-HI-HA
#  Kauai, US-HI-KA
#  Kahoolawe, US-HI-KH
#  Lanai, US-HI-LA
#  Maui, US-HI-MA
#  Molokai, US-HI-MO
#  Niihau, US-HI-NI
#  Oahu, US-HI-OA
#  PJM Interconnection, US-MIDA-PJM
#  Associated Electric Cooperative, US-MIDW-AECI
#  Louisville Gas and Electric Company and Kentucky Utilities, US-MIDW-LGEE
#  Midcontinent ISO, US-MIDW-MISO
#  ISO New England, US-NE-ISNE
#  Avista Corporation, US-NW-AVA
#  Bonneville Power Administration, US-NW-BPAT
#  Chelan County, US-NW-CHPD
#  Douglas County, US-NW-DOPD
#  Grant County, US-NW-GCPD
#  Gridforce Energy Management, US-NW-GRID
#  Idaho Power Company, US-NW-IPCO
#  Nevada Power Company, US-NW-NEVP
#  Northwestern Energy, US-NW-NWMT
#  Pacificorp East, US-NW-PACE
#  Pacificorp West, US-NW-PACW
#  Portland General Electric Company, US-NW-PGE
#  Public Service Company of Colorado, US-NW-PSCO
#  Puget Sound Energy, US-NW-PSEI
#  Seattle City Light, US-NW-SCL
#  City of Tacoma, US-NW-TPWR
#  Western Area Power Administration - Rocky Mountain Region, US-NW-WACM
#  Western Area Power Administration - Upper Great Plains West, US-NW-WAUW
#  New York ISO, US-NY-NYIS
#  Southeastern Power Administration, US-SE-SEPA
#  Southern Company Services, US-SE-SOCO
#  Arizona Public Service Company, US-SW-AZPS
#  El Paso Electric Company, US-SW-EPE
#  Public Service Company of New Mexico, US-SW-PNM
#  Salt River Project, US-SW-SRP
#  Tucson Electric Power Company, US-SW-TEPC
#  Western Area Power Administration - Desert Southwest Region, US-SW-WALC
#  Tennessee Valley Authority, US-TEN-TVA
#  Electric Reliability Council of Texas, US-TEX-ERCO
#  Uruguay, UY
#  Uzbekistan, UZ
#  Saint Vincent and the Grenadines, VC
#  Venezuela, VE
#  Virgin Islands, VI
#  Vietnam, VN
#  Central Vietnam, VN-C
#  Northern Vietnam, VN-N
#  Southern Vietnam, VN-S
#  Vanuatu, VU
#  Samoa, WS
#  Kosovo, XK
#  Northern Cyprus, XX
#  Yemen, YE
#  Mayotte, YT
#  South Africa, ZA
#  Zambia, ZM
#  Zimbabwe, ZW

# %% [markdown]
# ### Live Power Breakdown

# %% [markdown]
# Checking the API documentation different endpoints can be found to gather different type of data. For each of them, the possible HTTP requests are listed. Methods are almost always **GET** to stream the data.
# Let's have a look at the *live power breakdown*.

# %%
live_power_endpoint = "https://api.electricitymap.org/v3/power-breakdown/history"

# %% [markdown]
# The header section is always used for the authorization token (in this case).

# %%
headers = {'auth-token': my_token}

# %% [markdown]
# Parameters to be specified are listed in the documentation.

# %%
params = {'zone': "IT"}

# %% [markdown]
# Let's create the request and extract the data

# %%
response = requests.get(live_power_endpoint, headers=headers, params=params)
response.json()
# Out:
# {'zone': 'IT',
#  'history': [{'zone': 'IT',
#    'datetime': '2025-01-02T15:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-30T15:46:44.408Z',
#    'powerConsumptionBreakdown': {'nuclear': 2487,
#     'geothermal': 645,
#     'biomass': 549,
#     'coal': 1771,
#     'wind': 142,
#     'solar': 2744,
#     'hydro': 5313,
#     'gas': 15903,
#     'oil': 235,
#     'unknown': 4998,
#     'hydro discharge': 711,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 648,
#     'biomass': 488,
#     'coal': 1757,
#     'wind': 0,
#     'solar': 2688,
#     'hydro': 4828,
#     'gas': 15764,
#     'oil': 232,
#     'unknown': 5003,
#     'hydro discharge': 506,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 53,
#     'CH': 425,
#     'FR': 3260,
#     'GR': 0,
#     'ME': 35,
#     'MT': 0,
#     'SI': 0,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 64,
#     'ME': 0,
#     'MT': 18,
#     'SI': 75,
#     'FR-COR': 33},
#    'fossilFreePercentage': 35,
#    'renewablePercentage': 28,
#    'powerConsumptionTotal': 35498,
#    'powerProductionTotal': 31914,
#    'powerImportTotal': 3774,
#    'powerExportTotal': 189,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T16:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-30T16:47:47.619Z',
#    'powerConsumptionBreakdown': {'nuclear': 2119,
#     'geothermal': 646,
#     'biomass': 582,
#     'coal': 1871,
#     'wind': 121,
#     'solar': 81,
#     'hydro': 6276,
#     'gas': 16560,
#     'oil': 243,
#     'unknown': 5184,
#     'hydro discharge': 1199,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 649,
#     'biomass': 490,
#     'coal': 1829,
#     'wind': 0,
#     'solar': 68,
#     'hydro': 5675,
#     'gas': 16435,
#     'oil': 241,
#     'unknown': 5149,
#     'hydro discharge': 909,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 73,
#     'CH': 754,
#     'FR': 2535,
#     'GR': 0,
#     'ME': 44,
#     'MT': 0,
#     'SI': 152,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 55,
#     'ME': 0,
#     'MT': 32,
#     'SI': 0,
#     'FR-COR': 33},
#    'fossilFreePercentage': 32,
#    'renewablePercentage': 25,
#    'powerConsumptionTotal': 34882,
#    'powerProductionTotal': 31445,
#    'powerImportTotal': 3557,
#    'powerExportTotal': 120,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T17:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:24.565Z',
#    'createdAt': '2024-12-30T17:47:09.602Z',
#    'powerConsumptionBreakdown': {'nuclear': 1701,
#     'geothermal': 647,
#     'biomass': 591,
#     'coal': 1947,
#     'wind': 129,
#     'solar': 4,
#     'hydro': 6965,
#     'gas': 16906,
#     'oil': 248,
#     'unknown': 5305,
#     'hydro discharge': 1640,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 650,
#     'biomass': 492,
#     'coal': 1889,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 6398,
#     'gas': 16819,
#     'oil': 247,
#     'unknown': 5264,
#     'hydro discharge': 1336,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 71,
#     'CH': 834,
#     'FR': 2021,
#     'GR': 0,
#     'ME': 43,
#     'MT': 0,
#     'SI': 166,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 75,
#     'ME': 0,
#     'MT': 36,
#     'SI': 0,
#     'FR-COR': 34},
#    'fossilFreePercentage': 32,
#    'renewablePercentage': 28,
#    'powerConsumptionTotal': 36084,
#    'powerProductionTotal': 33094,
#    'powerImportTotal': 3135,
#    'powerExportTotal': 145,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T18:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:11.475Z',
#    'createdAt': '2024-12-30T18:49:16.826Z',
#    'powerConsumptionBreakdown': {'nuclear': 1690,
#     'geothermal': 648,
#     'biomass': 596,
#     'coal': 2000,
#     'wind': 175,
#     'solar': 0,
#     'hydro': 6935,
#     'gas': 17003,
#     'oil': 251,
#     'unknown': 5308,
#     'hydro discharge': 1609,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 651,
#     'biomass': 493,
#     'coal': 1911,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 6380,
#     'gas': 16868,
#     'oil': 248,
#     'unknown': 5266,
#     'hydro discharge': 1355,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 66,
#     'CH': 850,
#     'FR': 2040,
#     'GR': 0,
#     'ME': 67,
#     'MT': 0,
#     'SI': 124,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 40,
#     'ME': 0,
#     'MT': 34,
#     'SI': 0,
#     'FR-COR': 33},
#    'fossilFreePercentage': 32,
#    'renewablePercentage': 27,
#    'powerConsumptionTotal': 36212,
#    'powerProductionTotal': 33173,
#    'powerImportTotal': 3146,
#    'powerExportTotal': 107,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T19:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:24.565Z',
#    'createdAt': '2024-12-30T19:46:07.184Z',
#    'powerConsumptionBreakdown': {'nuclear': 1862,
#     'geothermal': 649,
#     'biomass': 588,
#     'coal': 2001,
#     'wind': 208,
#     'solar': 0,
#     'hydro': 6110,
#     'gas': 16684,
#     'oil': 246,
#     'unknown': 5144,
#     'hydro discharge': 1115,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 652,
#     'biomass': 494,
#     'coal': 1878,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 5579,
#     'gas': 16493,
#     'oil': 244,
#     'unknown': 5115,
#     'hydro discharge': 948,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 72,
#     'CH': 733,
#     'FR': 2180,
#     'GR': 25,
#     'ME': 95,
#     'MT': 0,
#     'SI': 178,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 47,
#     'SI': 0,
#     'FR-COR': 32},
#    'fossilFreePercentage': 30,
#    'renewablePercentage': 25,
#    'powerConsumptionTotal': 34607,
#    'powerProductionTotal': 31403,
#    'powerImportTotal': 3282,
#    'powerExportTotal': 78,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T20:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-30T20:46:32.843Z',
#    'powerConsumptionBreakdown': {'nuclear': 2079,
#     'geothermal': 650,
#     'biomass': 580,
#     'coal': 1921,
#     'wind': 208,
#     'solar': 0,
#     'hydro': 5101,
#     'gas': 15794,
#     'oil': 238,
#     'unknown': 4846,
#     'hydro discharge': 686,
#     'battery discharge': 1},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 653,
#     'biomass': 495,
#     'coal': 1812,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 4612,
#     'gas': 15627,
#     'oil': 235,
#     'unknown': 4825,
#     'hydro discharge': 552,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 66,
#     'CH': 677,
#     'FR': 2434,
#     'GR': 0,
#     'ME': 109,
#     'MT': 0,
#     'SI': 90,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 10,
#     'ME': 0,
#     'MT': 39,
#     'SI': 0,
#     'FR-COR': 33},
#    'fossilFreePercentage': 29,
#    'renewablePercentage': 22,
#    'powerConsumptionTotal': 32105,
#    'powerProductionTotal': 28811,
#    'powerImportTotal': 3375,
#    'powerExportTotal': 81,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T21:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-30T21:47:11.071Z',
#    'powerConsumptionBreakdown': {'nuclear': 1865,
#     'geothermal': 651,
#     'biomass': 584,
#     'coal': 1901,
#     'wind': 254,
#     'solar': 0,
#     'hydro': 4312,
#     'gas': 14644,
#     'oil': 230,
#     'unknown': 4540,
#     'hydro discharge': 413,
#     'battery discharge': 1},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 653,
#     'biomass': 495,
#     'coal': 1741,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 3894,
#     'gas': 14462,
#     'oil': 226,
#     'unknown': 4520,
#     'hydro discharge': 304,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 70,
#     'CH': 732,
#     'FR': 2085,
#     'GR': 0,
#     'ME': 110,
#     'MT': 0,
#     'SI': 167,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 12,
#     'ME': 0,
#     'MT': 24,
#     'SI': 0,
#     'FR-COR': 32},
#    'fossilFreePercentage': 28,
#    'renewablePercentage': 21,
#    'powerConsumptionTotal': 29393,
#    'powerProductionTotal': 26296,
#    'powerImportTotal': 3164,
#    'powerExportTotal': 67,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T22:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:11.475Z',
#    'createdAt': '2024-12-30T22:48:39.646Z',
#    'powerConsumptionBreakdown': {'nuclear': 2425,
#     'geothermal': 650,
#     'biomass': 738,
#     'coal': 2355,
#     'wind': 860,
#     'solar': 0,
#     'hydro': 4271,
#     'gas': 13608,
#     'oil': 214,
#     'unknown': 4238,
#     'hydro discharge': 341,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 654,
#     'biomass': 494,
#     'coal': 1674,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 3436,
#     'gas': 13035,
#     'oil': 206,
#     'unknown': 4164,
#     'hydro discharge': 121,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 162,
#     'CH': 2773,
#     'FR': 1588,
#     'GR': 375,
#     'ME': 442,
#     'MT': 0,
#     'SI': 646,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 34,
#     'SI': 0,
#     'FR-COR': 33},
#    'fossilFreePercentage': 31,
#    'renewablePercentage': 23,
#    'powerConsumptionTotal': 29700,
#    'powerProductionTotal': 23782,
#    'powerImportTotal': 5985,
#    'powerExportTotal': 67,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-02T23:00:00.000Z',
#    'updatedAt': '2025-01-03T10:47:14.338Z',
#    'createdAt': '2024-12-30T23:46:47.295Z',
#    'powerConsumptionBreakdown': {'nuclear': 1902,
#     'geothermal': 647,
#     'biomass': 585,
#     'coal': 1871,
#     'wind': 325,
#     'solar': 0,
#     'hydro': 3476,
#     'gas': 12098,
#     'oil': 193,
#     'unknown': 3871,
#     'hydro discharge': 72,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 654,
#     'biomass': 496,
#     'coal': 1615,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 3102,
#     'gas': 11944,
#     'oil': 191,
#     'unknown': 3880,
#     'hydro discharge': -99,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 68,
#     'CH': 496,
#     'FR': 1743,
#     'GR': 76,
#     'ME': 95,
#     'MT': 0,
#     'SI': 843,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 29,
#     'SI': 0,
#     'FR-COR': 34},
#    'fossilFreePercentage': 28,
#    'renewablePercentage': 20,
#    'powerConsumptionTotal': 25041,
#    'powerProductionTotal': 21882,
#    'powerImportTotal': 3321,
#    'powerExportTotal': 62,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T00:00:00.000Z',
#    'updatedAt': '2025-01-03T10:46:54.415Z',
#    'createdAt': '2024-12-31T00:45:53.572Z',
#    'powerConsumptionBreakdown': {'nuclear': 1922,
#     'geothermal': 651,
#     'biomass': 578,
#     'coal': 1811,
#     'wind': 325,
#     'solar': 0,
#     'hydro': 3200,
#     'gas': 11514,
#     'oil': 188,
#     'unknown': 3672,
#     'hydro discharge': 56,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 655,
#     'biomass': 496,
#     'coal': 1560,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 2890,
#     'gas': 11474,
#     'oil': 188,
#     'unknown': 3714,
#     'hydro discharge': -301,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 70,
#     'CH': 452,
#     'FR': 1701,
#     'GR': 43,
#     'ME': 117,
#     'MT': 0,
#     'SI': 921,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 29,
#     'SI': 0,
#     'FR-COR': 32},
#    'fossilFreePercentage': 28,
#    'renewablePercentage': 20,
#    'powerConsumptionTotal': 23917,
#    'powerProductionTotal': 20976,
#    'powerImportTotal': 3303,
#    'powerExportTotal': 61,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T01:00:00.000Z',
#    'updatedAt': '2025-01-03T10:46:54.415Z',
#    'createdAt': '2024-12-31T01:46:51.205Z',
#    'powerConsumptionBreakdown': {'nuclear': 1667,
#     'geothermal': 651,
#     'biomass': 575,
#     'coal': 1786,
#     'wind': 326,
#     'solar': 0,
#     'hydro': 3048,
#     'gas': 11251,
#     'oil': 184,
#     'unknown': 3560,
#     'hydro discharge': 52,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 655,
#     'biomass': 496,
#     'coal': 1523,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 2793,
#     'gas': 11284,
#     'oil': 185,
#     'unknown': 3626,
#     'hydro discharge': -452,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 72,
#     'CH': 502,
#     'FR': 1303,
#     'ME': 131,
#     'MT': 0,
#     'SI': 1040,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'ME': 0,
#     'MT': 26,
#     'SI': 0,
#     'FR-COR': 29},
#    'fossilFreePercentage': 27,
#    'renewablePercentage': 20,
#    'powerConsumptionTotal': 23101,
#    'powerProductionTotal': 20561,
#    'powerImportTotal': 3047,
#    'powerExportTotal': 55,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T02:00:00.000Z',
#    'updatedAt': '2025-01-03T10:47:09.771Z',
#    'createdAt': '2024-12-31T02:44:41.398Z',
#    'powerConsumptionBreakdown': {'nuclear': 1451,
#     'geothermal': 650,
#     'biomass': 556,
#     'coal': 1734,
#     'wind': 268,
#     'solar': 0,
#     'hydro': 2979,
#     'gas': 11156,
#     'oil': 182,
#     'unknown': 3532,
#     'hydro discharge': 46,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 655,
#     'biomass': 495,
#     'coal': 1517,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 2790,
#     'gas': 11269,
#     'oil': 184,
#     'unknown': 3614,
#     'hydro discharge': -530,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 53,
#     'CH': 422,
#     'FR': 1033,
#     'GR': 0,
#     'ME': 103,
#     'MT': 0,
#     'SI': 1016,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 20,
#     'ME': 0,
#     'MT': 19,
#     'SI': 0,
#     'FR-COR': 26},
#    'fossilFreePercentage': 26,
#    'renewablePercentage': 20,
#    'powerConsumptionTotal': 22554,
#    'powerProductionTotal': 20523,
#    'powerImportTotal': 2626,
#    'powerExportTotal': 65,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T03:00:00.000Z',
#    'updatedAt': '2025-01-03T10:47:09.771Z',
#    'createdAt': '2024-12-31T03:44:25.469Z',
#    'powerConsumptionBreakdown': {'nuclear': 1555,
#     'geothermal': 650,
#     'biomass': 561,
#     'coal': 1773,
#     'wind': 288,
#     'solar': 0,
#     'hydro': 3108,
#     'gas': 11505,
#     'oil': 183,
#     'unknown': 3662,
#     'hydro discharge': 58,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 655,
#     'biomass': 495,
#     'coal': 1545,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 2890,
#     'gas': 11611,
#     'oil': 184,
#     'unknown': 3730,
#     'hydro discharge': -456,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 67,
#     'CH': 585,
#     'FR': 1149,
#     'GR': 0,
#     'ME': 149,
#     'MT': 0,
#     'SI': 826,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 35,
#     'ME': 0,
#     'MT': 26,
#     'SI': 0,
#     'FR-COR': 26},
#    'fossilFreePercentage': 27,
#    'renewablePercentage': 20,
#    'powerConsumptionTotal': 23343,
#    'powerProductionTotal': 21110,
#    'powerImportTotal': 2775,
#    'powerExportTotal': 87,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T04:00:00.000Z',
#    'updatedAt': '2025-01-03T10:47:09.771Z',
#    'createdAt': '2024-12-31T04:44:57.310Z',
#    'powerConsumptionBreakdown': {'nuclear': 1648,
#     'geothermal': 652,
#     'biomass': 565,
#     'coal': 1809,
#     'wind': 287,
#     'solar': 1,
#     'hydro': 3593,
#     'gas': 12658,
#     'oil': 191,
#     'unknown': 4038,
#     'hydro discharge': 73,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 654,
#     'biomass': 493,
#     'coal': 1621,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 3298,
#     'gas': 12653,
#     'oil': 187,
#     'unknown': 4061,
#     'hydro discharge': -161,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 52,
#     'CH': 469,
#     'FR': 1401,
#     'GR': 0,
#     'ME': 109,
#     'MT': 0,
#     'SI': 783,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 56,
#     'ME': 0,
#     'MT': 24,
#     'SI': 0,
#     'FR-COR': 25},
#    'fossilFreePercentage': 27,
#    'renewablePercentage': 20,
#    'powerConsumptionTotal': 25516,
#    'powerProductionTotal': 22968,
#    'powerImportTotal': 2814,
#    'powerExportTotal': 105,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T05:00:00.000Z',
#    'updatedAt': '2025-01-03T10:47:09.771Z',
#    'createdAt': '2024-12-31T05:45:09.857Z',
#    'powerConsumptionBreakdown': {'nuclear': 1845,
#     'geothermal': 653,
#     'biomass': 590,
#     'coal': 1932,
#     'wind': 358,
#     'solar': 0,
#     'hydro': 4551,
#     'gas': 14206,
#     'oil': 205,
#     'unknown': 4528,
#     'hydro discharge': 460,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 653,
#     'biomass': 490,
#     'coal': 1717,
#     'wind': 0,
#     'solar': 0,
#     'hydro': 4101,
#     'gas': 14043,
#     'oil': 194,
#     'unknown': 4514,
#     'hydro discharge': 305,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 67,
#     'CH': 658,
#     'FR': 1621,
#     'GR': 0,
#     'ME': 120,
#     'MT': 0,
#     'SI': 913,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 6,
#     'ME': 0,
#     'MT': 32,
#     'SI': 0,
#     'FR-COR': 31},
#    'fossilFreePercentage': 29,
#    'renewablePercentage': 22,
#    'powerConsumptionTotal': 29328,
#    'powerProductionTotal': 26017,
#    'powerImportTotal': 3379,
#    'powerExportTotal': 68,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T06:00:00.000Z',
#    'updatedAt': '2025-01-03T10:47:09.771Z',
#    'createdAt': '2024-12-31T06:45:39.797Z',
#    'powerConsumptionBreakdown': {'nuclear': 1815,
#     'geothermal': 652,
#     'biomass': 583,
#     'coal': 1932,
#     'wind': 320,
#     'solar': 2156,
#     'hydro': 5496,
#     'gas': 15012,
#     'oil': 215,
#     'unknown': 4828,
#     'hydro discharge': 881,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 651,
#     'biomass': 487,
#     'coal': 1775,
#     'wind': 0,
#     'solar': 2177,
#     'hydro': 4929,
#     'gas': 14885,
#     'oil': 201,
#     'unknown': 4810,
#     'hydro discharge': 680,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 70,
#     'CH': 674,
#     'FR': 1715,
#     'GR': 0,
#     'ME': 94,
#     'MT': 0,
#     'SI': 913,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 123,
#     'ME': 0,
#     'MT': 17,
#     'SI': 0,
#     'FR-COR': 34},
#    'fossilFreePercentage': 35,
#    'renewablePercentage': 30,
#    'powerConsumptionTotal': 33889,
#    'powerProductionTotal': 30596,
#    'powerImportTotal': 3466,
#    'powerExportTotal': 174,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T07:00:00.000Z',
#    'updatedAt': '2025-01-03T11:45:42.468Z',
#    'createdAt': '2024-12-31T07:48:30.488Z',
#    'powerConsumptionBreakdown': {'nuclear': 1727,
#     'geothermal': 650,
#     'biomass': 590,
#     'coal': 1929,
#     'wind': 310,
#     'solar': 4095,
#     'hydro': 5775,
#     'gas': 15180,
#     'oil': 218,
#     'unknown': 4931,
#     'hydro discharge': 900,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 649,
#     'biomass': 485,
#     'coal': 1780,
#     'wind': 0,
#     'solar': 4090,
#     'hydro': 5211,
#     'gas': 15003,
#     'oil': 206,
#     'unknown': 4898,
#     'hydro discharge': 709,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 72,
#     'CH': 886,
#     'FR': 1793,
#     'GR': 0,
#     'ME': 119,
#     'MT': 0,
#     'SI': 473,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 15,
#     'ME': 0,
#     'MT': 23,
#     'SI': 0,
#     'FR-COR': 33},
#    'fossilFreePercentage': 39,
#    'renewablePercentage': 34,
#    'powerConsumptionTotal': 36305,
#    'powerProductionTotal': 33032,
#    'powerImportTotal': 3343,
#    'powerExportTotal': 70,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T08:00:00.000Z',
#    'updatedAt': '2025-01-03T12:46:18.203Z',
#    'createdAt': '2024-12-31T08:47:46.247Z',
#    'powerConsumptionBreakdown': {'nuclear': 1881,
#     'geothermal': 648,
#     'biomass': 576,
#     'coal': 1874,
#     'wind': 303,
#     'solar': 5930,
#     'hydro': 5478,
#     'gas': 14974,
#     'oil': 220,
#     'unknown': 4891,
#     'hydro discharge': 698,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 648,
#     'biomass': 483,
#     'coal': 1747,
#     'wind': 0,
#     'solar': 5810,
#     'hydro': 4900,
#     'gas': 14792,
#     'oil': 208,
#     'unknown': 4866,
#     'hydro discharge': 520,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 72,
#     'CH': 744,
#     'FR': 2205,
#     'GR': 100,
#     'ME': 118,
#     'MT': 0,
#     'SI': 318,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 25,
#     'SI': 0,
#     'FR-COR': 33},
#    'fossilFreePercentage': 41,
#    'renewablePercentage': 36,
#    'powerConsumptionTotal': 37473,
#    'powerProductionTotal': 33975,
#    'powerImportTotal': 3557,
#    'powerExportTotal': 58,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T09:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:11.475Z',
#    'createdAt': '2024-12-31T09:46:56.462Z',
#    'powerConsumptionBreakdown': {'nuclear': 1924,
#     'geothermal': 647,
#     'biomass': 562,
#     'coal': 1820,
#     'wind': 289,
#     'solar': 7189,
#     'hydro': 4961,
#     'gas': 14680,
#     'oil': 221,
#     'unknown': 4798,
#     'hydro discharge': 463,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 647,
#     'biomass': 483,
#     'coal': 1704,
#     'wind': 0,
#     'solar': 6982,
#     'hydro': 4436,
#     'gas': 14499,
#     'oil': 208,
#     'unknown': 4786,
#     'hydro discharge': 334,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 50,
#     'CH': 513,
#     'FR': 2327,
#     'GR': 94,
#     'ME': 85,
#     'MT': 0,
#     'SI': 470,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 29,
#     'SI': 0,
#     'FR-COR': 33},
#    'fossilFreePercentage': 43,
#    'renewablePercentage': 38,
#    'powerConsumptionTotal': 37555,
#    'powerProductionTotal': 34079,
#    'powerImportTotal': 3539,
#    'powerExportTotal': 62,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T10:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-31T10:47:03.758Z',
#    'powerConsumptionBreakdown': {'nuclear': 2020,
#     'geothermal': 647,
#     'biomass': 574,
#     'coal': 1824,
#     'wind': 337,
#     'solar': 7885,
#     'hydro': 4489,
#     'gas': 14375,
#     'oil': 222,
#     'unknown': 4660,
#     'hydro discharge': 257,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 647,
#     'biomass': 483,
#     'coal': 1659,
#     'wind': 0,
#     'solar': 7556,
#     'hydro': 3934,
#     'gas': 14168,
#     'oil': 209,
#     'unknown': 4645,
#     'hydro discharge': 142,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 70,
#     'CH': 597,
#     'FR': 2277,
#     'GR': 125,
#     'ME': 113,
#     'MT': 0,
#     'SI': 735,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 40,
#     'SI': 0,
#     'FR-COR': 28},
#    'fossilFreePercentage': 43,
#    'renewablePercentage': 38,
#    'powerConsumptionTotal': 37292,
#    'powerProductionTotal': 33443,
#    'powerImportTotal': 3916,
#    'powerExportTotal': 68,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T11:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-31T11:47:40.607Z',
#    'powerConsumptionBreakdown': {'nuclear': 2034,
#     'geothermal': 648,
#     'biomass': 559,
#     'coal': 1758,
#     'wind': 318,
#     'solar': 7928,
#     'hydro': 4093,
#     'gas': 14069,
#     'oil': 222,
#     'unknown': 4532,
#     'hydro discharge': 121,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 647,
#     'biomass': 483,
#     'coal': 1624,
#     'wind': 0,
#     'solar': 7602,
#     'hydro': 3630,
#     'gas': 13908,
#     'oil': 211,
#     'unknown': 4528,
#     'hydro discharge': -12,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 53,
#     'CH': 367,
#     'FR': 2381,
#     'GR': 94,
#     'ME': 82,
#     'MT': 0,
#     'SI': 740,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 29,
#     'SI': 0,
#     'FR-COR': 27},
#    'fossilFreePercentage': 43,
#    'renewablePercentage': 38,
#    'powerConsumptionTotal': 36282,
#    'powerProductionTotal': 32633,
#    'powerImportTotal': 3718,
#    'powerExportTotal': 56,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T12:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-31T12:45:51.790Z',
#    'powerConsumptionBreakdown': {'nuclear': 2002,
#     'geothermal': 647,
#     'biomass': 553,
#     'coal': 1705,
#     'wind': 291,
#     'solar': 7451,
#     'hydro': 4036,
#     'gas': 14126,
#     'oil': 225,
#     'unknown': 4560,
#     'hydro discharge': 104,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 647,
#     'biomass': 484,
#     'coal': 1617,
#     'wind': 0,
#     'solar': 7123,
#     'hydro': 3631,
#     'gas': 14006,
#     'oil': 214,
#     'unknown': 4558,
#     'hydro discharge': -51,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 189,
#     'CH': 367,
#     'FR': 2512,
#     'GR': 126,
#     'ME': 82,
#     'MT': 0,
#     'SI': 244,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0,
#     'CH': 0,
#     'FR': 0,
#     'GR': 0,
#     'ME': 0,
#     'MT': 33,
#     'SI': 0,
#     'FR-COR': 16},
#    'fossilFreePercentage': 42,
#    'renewablePercentage': 37,
#    'powerConsumptionTotal': 35700,
#    'powerProductionTotal': 32280,
#    'powerImportTotal': 3519,
#    'powerExportTotal': 49,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T13:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:25.531Z',
#    'createdAt': '2024-12-31T13:50:58.277Z',
#    'powerConsumptionBreakdown': {'nuclear': 1817,
#     'geothermal': 647,
#     'biomass': 532,
#     'coal': 1665,
#     'wind': 245,
#     'solar': 6341,
#     'hydro': 4143,
#     'gas': 14532,
#     'oil': 223,
#     'unknown': 4677,
#     'hydro discharge': 131,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 647,
#     'biomass': 483,
#     'coal': 1642,
#     'wind': 5,
#     'solar': 6109,
#     'hydro': 3834,
#     'gas': 14414,
#     'oil': 218,
#     'unknown': 4686,
#     'hydro discharge': 43,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 306,
#     'FR': 2504,
#     'GR': 104,
#     'MT': 0,
#     'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0, 'FR': 0, 'GR': 0, 'MT': 33, 'FR-COR': 10},
#    'fossilFreePercentage': 40,
#    'renewablePercentage': 34,
#    'powerConsumptionTotal': 34953,
#    'powerProductionTotal': 32081,
#    'powerImportTotal': 2915,
#    'powerExportTotal': 43,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'},
#   {'zone': 'IT',
#    'datetime': '2025-01-03T14:00:00.000Z',
#    'updatedAt': '2025-01-03T13:45:11.475Z',
#    'createdAt': '2024-12-31T14:48:20.926Z',
#    'powerConsumptionBreakdown': {'nuclear': 1949,
#     'geothermal': 650,
#     'biomass': 531,
#     'coal': 1709,
#     'wind': 206,
#     'solar': 4780,
#     'hydro': 4553,
#     'gas': 15256,
#     'oil': 228,
#     'unknown': 4882,
#     'hydro discharge': 281,
#     'battery discharge': 0},
#    'powerProductionBreakdown': {'nuclear': None,
#     'geothermal': 647,
#     'biomass': 485,
#     'coal': 1691,
#     'wind': 7,
#     'solar': 4550,
#     'hydro': 4232,
#     'gas': 15046,
#     'oil': 224,
#     'unknown': 4862,
#     'hydro discharge': 246,
#     'battery discharge': None},
#    'powerImportBreakdown': {'AT': 306, 'FR': 2646, 'GR': 93, 'FR-COR': 0},
#    'powerExportBreakdown': {'AT': 0, 'FR': 0, 'GR': 0, 'FR-COR': 10},
#    'fossilFreePercentage': 37,
#    'renewablePercentage': 31,
#    'powerConsumptionTotal': 35026,
#    'powerProductionTotal': 31990,
#    'powerImportTotal': 3045,
#    'powerExportTotal': 10,
#    'isEstimated': True,
#    'estimationMethod': 'TIME_SLICER_AVERAGE'}]}

# %% [markdown]
# Let's extract the data and try to visualize

# %%
hystorical_data = response.json()["history"]
hystorical_data
# Out:
# [{'zone': 'IT',
#   'datetime': '2025-01-02T15:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-30T15:46:44.408Z',
#   'powerConsumptionBreakdown': {'nuclear': 2487,
#    'geothermal': 645,
#    'biomass': 549,
#    'coal': 1771,
#    'wind': 142,
#    'solar': 2744,
#    'hydro': 5313,
#    'gas': 15903,
#    'oil': 235,
#    'unknown': 4998,
#    'hydro discharge': 711,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 648,
#    'biomass': 488,
#    'coal': 1757,
#    'wind': 0,
#    'solar': 2688,
#    'hydro': 4828,
#    'gas': 15764,
#    'oil': 232,
#    'unknown': 5003,
#    'hydro discharge': 506,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 53,
#    'CH': 425,
#    'FR': 3260,
#    'GR': 0,
#    'ME': 35,
#    'MT': 0,
#    'SI': 0,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 64,
#    'ME': 0,
#    'MT': 18,
#    'SI': 75,
#    'FR-COR': 33},
#   'fossilFreePercentage': 35,
#   'renewablePercentage': 28,
#   'powerConsumptionTotal': 35498,
#   'powerProductionTotal': 31914,
#   'powerImportTotal': 3774,
#   'powerExportTotal': 189,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T16:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-30T16:47:47.619Z',
#   'powerConsumptionBreakdown': {'nuclear': 2119,
#    'geothermal': 646,
#    'biomass': 582,
#    'coal': 1871,
#    'wind': 121,
#    'solar': 81,
#    'hydro': 6276,
#    'gas': 16560,
#    'oil': 243,
#    'unknown': 5184,
#    'hydro discharge': 1199,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 649,
#    'biomass': 490,
#    'coal': 1829,
#    'wind': 0,
#    'solar': 68,
#    'hydro': 5675,
#    'gas': 16435,
#    'oil': 241,
#    'unknown': 5149,
#    'hydro discharge': 909,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 73,
#    'CH': 754,
#    'FR': 2535,
#    'GR': 0,
#    'ME': 44,
#    'MT': 0,
#    'SI': 152,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 55,
#    'ME': 0,
#    'MT': 32,
#    'SI': 0,
#    'FR-COR': 33},
#   'fossilFreePercentage': 32,
#   'renewablePercentage': 25,
#   'powerConsumptionTotal': 34882,
#   'powerProductionTotal': 31445,
#   'powerImportTotal': 3557,
#   'powerExportTotal': 120,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T17:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:24.565Z',
#   'createdAt': '2024-12-30T17:47:09.602Z',
#   'powerConsumptionBreakdown': {'nuclear': 1701,
#    'geothermal': 647,
#    'biomass': 591,
#    'coal': 1947,
#    'wind': 129,
#    'solar': 4,
#    'hydro': 6965,
#    'gas': 16906,
#    'oil': 248,
#    'unknown': 5305,
#    'hydro discharge': 1640,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 650,
#    'biomass': 492,
#    'coal': 1889,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 6398,
#    'gas': 16819,
#    'oil': 247,
#    'unknown': 5264,
#    'hydro discharge': 1336,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 71,
#    'CH': 834,
#    'FR': 2021,
#    'GR': 0,
#    'ME': 43,
#    'MT': 0,
#    'SI': 166,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 75,
#    'ME': 0,
#    'MT': 36,
#    'SI': 0,
#    'FR-COR': 34},
#   'fossilFreePercentage': 32,
#   'renewablePercentage': 28,
#   'powerConsumptionTotal': 36084,
#   'powerProductionTotal': 33094,
#   'powerImportTotal': 3135,
#   'powerExportTotal': 145,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T18:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:11.475Z',
#   'createdAt': '2024-12-30T18:49:16.826Z',
#   'powerConsumptionBreakdown': {'nuclear': 1690,
#    'geothermal': 648,
#    'biomass': 596,
#    'coal': 2000,
#    'wind': 175,
#    'solar': 0,
#    'hydro': 6935,
#    'gas': 17003,
#    'oil': 251,
#    'unknown': 5308,
#    'hydro discharge': 1609,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 651,
#    'biomass': 493,
#    'coal': 1911,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 6380,
#    'gas': 16868,
#    'oil': 248,
#    'unknown': 5266,
#    'hydro discharge': 1355,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 66,
#    'CH': 850,
#    'FR': 2040,
#    'GR': 0,
#    'ME': 67,
#    'MT': 0,
#    'SI': 124,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 40,
#    'ME': 0,
#    'MT': 34,
#    'SI': 0,
#    'FR-COR': 33},
#   'fossilFreePercentage': 32,
#   'renewablePercentage': 27,
#   'powerConsumptionTotal': 36212,
#   'powerProductionTotal': 33173,
#   'powerImportTotal': 3146,
#   'powerExportTotal': 107,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T19:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:24.565Z',
#   'createdAt': '2024-12-30T19:46:07.184Z',
#   'powerConsumptionBreakdown': {'nuclear': 1862,
#    'geothermal': 649,
#    'biomass': 588,
#    'coal': 2001,
#    'wind': 208,
#    'solar': 0,
#    'hydro': 6110,
#    'gas': 16684,
#    'oil': 246,
#    'unknown': 5144,
#    'hydro discharge': 1115,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 652,
#    'biomass': 494,
#    'coal': 1878,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 5579,
#    'gas': 16493,
#    'oil': 244,
#    'unknown': 5115,
#    'hydro discharge': 948,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 72,
#    'CH': 733,
#    'FR': 2180,
#    'GR': 25,
#    'ME': 95,
#    'MT': 0,
#    'SI': 178,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 47,
#    'SI': 0,
#    'FR-COR': 32},
#   'fossilFreePercentage': 30,
#   'renewablePercentage': 25,
#   'powerConsumptionTotal': 34607,
#   'powerProductionTotal': 31403,
#   'powerImportTotal': 3282,
#   'powerExportTotal': 78,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T20:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-30T20:46:32.843Z',
#   'powerConsumptionBreakdown': {'nuclear': 2079,
#    'geothermal': 650,
#    'biomass': 580,
#    'coal': 1921,
#    'wind': 208,
#    'solar': 0,
#    'hydro': 5101,
#    'gas': 15794,
#    'oil': 238,
#    'unknown': 4846,
#    'hydro discharge': 686,
#    'battery discharge': 1},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 653,
#    'biomass': 495,
#    'coal': 1812,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 4612,
#    'gas': 15627,
#    'oil': 235,
#    'unknown': 4825,
#    'hydro discharge': 552,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 66,
#    'CH': 677,
#    'FR': 2434,
#    'GR': 0,
#    'ME': 109,
#    'MT': 0,
#    'SI': 90,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 10,
#    'ME': 0,
#    'MT': 39,
#    'SI': 0,
#    'FR-COR': 33},
#   'fossilFreePercentage': 29,
#   'renewablePercentage': 22,
#   'powerConsumptionTotal': 32105,
#   'powerProductionTotal': 28811,
#   'powerImportTotal': 3375,
#   'powerExportTotal': 81,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T21:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-30T21:47:11.071Z',
#   'powerConsumptionBreakdown': {'nuclear': 1865,
#    'geothermal': 651,
#    'biomass': 584,
#    'coal': 1901,
#    'wind': 254,
#    'solar': 0,
#    'hydro': 4312,
#    'gas': 14644,
#    'oil': 230,
#    'unknown': 4540,
#    'hydro discharge': 413,
#    'battery discharge': 1},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 653,
#    'biomass': 495,
#    'coal': 1741,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 3894,
#    'gas': 14462,
#    'oil': 226,
#    'unknown': 4520,
#    'hydro discharge': 304,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 70,
#    'CH': 732,
#    'FR': 2085,
#    'GR': 0,
#    'ME': 110,
#    'MT': 0,
#    'SI': 167,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 12,
#    'ME': 0,
#    'MT': 24,
#    'SI': 0,
#    'FR-COR': 32},
#   'fossilFreePercentage': 28,
#   'renewablePercentage': 21,
#   'powerConsumptionTotal': 29393,
#   'powerProductionTotal': 26296,
#   'powerImportTotal': 3164,
#   'powerExportTotal': 67,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T22:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:11.475Z',
#   'createdAt': '2024-12-30T22:48:39.646Z',
#   'powerConsumptionBreakdown': {'nuclear': 2425,
#    'geothermal': 650,
#    'biomass': 738,
#    'coal': 2355,
#    'wind': 860,
#    'solar': 0,
#    'hydro': 4271,
#    'gas': 13608,
#    'oil': 214,
#    'unknown': 4238,
#    'hydro discharge': 341,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 654,
#    'biomass': 494,
#    'coal': 1674,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 3436,
#    'gas': 13035,
#    'oil': 206,
#    'unknown': 4164,
#    'hydro discharge': 121,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 162,
#    'CH': 2773,
#    'FR': 1588,
#    'GR': 375,
#    'ME': 442,
#    'MT': 0,
#    'SI': 646,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 34,
#    'SI': 0,
#    'FR-COR': 33},
#   'fossilFreePercentage': 31,
#   'renewablePercentage': 23,
#   'powerConsumptionTotal': 29700,
#   'powerProductionTotal': 23782,
#   'powerImportTotal': 5985,
#   'powerExportTotal': 67,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-02T23:00:00.000Z',
#   'updatedAt': '2025-01-03T10:47:14.338Z',
#   'createdAt': '2024-12-30T23:46:47.295Z',
#   'powerConsumptionBreakdown': {'nuclear': 1902,
#    'geothermal': 647,
#    'biomass': 585,
#    'coal': 1871,
#    'wind': 325,
#    'solar': 0,
#    'hydro': 3476,
#    'gas': 12098,
#    'oil': 193,
#    'unknown': 3871,
#    'hydro discharge': 72,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 654,
#    'biomass': 496,
#    'coal': 1615,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 3102,
#    'gas': 11944,
#    'oil': 191,
#    'unknown': 3880,
#    'hydro discharge': -99,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 68,
#    'CH': 496,
#    'FR': 1743,
#    'GR': 76,
#    'ME': 95,
#    'MT': 0,
#    'SI': 843,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 29,
#    'SI': 0,
#    'FR-COR': 34},
#   'fossilFreePercentage': 28,
#   'renewablePercentage': 20,
#   'powerConsumptionTotal': 25041,
#   'powerProductionTotal': 21882,
#   'powerImportTotal': 3321,
#   'powerExportTotal': 62,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T00:00:00.000Z',
#   'updatedAt': '2025-01-03T10:46:54.415Z',
#   'createdAt': '2024-12-31T00:45:53.572Z',
#   'powerConsumptionBreakdown': {'nuclear': 1922,
#    'geothermal': 651,
#    'biomass': 578,
#    'coal': 1811,
#    'wind': 325,
#    'solar': 0,
#    'hydro': 3200,
#    'gas': 11514,
#    'oil': 188,
#    'unknown': 3672,
#    'hydro discharge': 56,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 655,
#    'biomass': 496,
#    'coal': 1560,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 2890,
#    'gas': 11474,
#    'oil': 188,
#    'unknown': 3714,
#    'hydro discharge': -301,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 70,
#    'CH': 452,
#    'FR': 1701,
#    'GR': 43,
#    'ME': 117,
#    'MT': 0,
#    'SI': 921,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 29,
#    'SI': 0,
#    'FR-COR': 32},
#   'fossilFreePercentage': 28,
#   'renewablePercentage': 20,
#   'powerConsumptionTotal': 23917,
#   'powerProductionTotal': 20976,
#   'powerImportTotal': 3303,
#   'powerExportTotal': 61,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T01:00:00.000Z',
#   'updatedAt': '2025-01-03T10:46:54.415Z',
#   'createdAt': '2024-12-31T01:46:51.205Z',
#   'powerConsumptionBreakdown': {'nuclear': 1667,
#    'geothermal': 651,
#    'biomass': 575,
#    'coal': 1786,
#    'wind': 326,
#    'solar': 0,
#    'hydro': 3048,
#    'gas': 11251,
#    'oil': 184,
#    'unknown': 3560,
#    'hydro discharge': 52,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 655,
#    'biomass': 496,
#    'coal': 1523,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 2793,
#    'gas': 11284,
#    'oil': 185,
#    'unknown': 3626,
#    'hydro discharge': -452,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 72,
#    'CH': 502,
#    'FR': 1303,
#    'ME': 131,
#    'MT': 0,
#    'SI': 1040,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'ME': 0,
#    'MT': 26,
#    'SI': 0,
#    'FR-COR': 29},
#   'fossilFreePercentage': 27,
#   'renewablePercentage': 20,
#   'powerConsumptionTotal': 23101,
#   'powerProductionTotal': 20561,
#   'powerImportTotal': 3047,
#   'powerExportTotal': 55,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T02:00:00.000Z',
#   'updatedAt': '2025-01-03T10:47:09.771Z',
#   'createdAt': '2024-12-31T02:44:41.398Z',
#   'powerConsumptionBreakdown': {'nuclear': 1451,
#    'geothermal': 650,
#    'biomass': 556,
#    'coal': 1734,
#    'wind': 268,
#    'solar': 0,
#    'hydro': 2979,
#    'gas': 11156,
#    'oil': 182,
#    'unknown': 3532,
#    'hydro discharge': 46,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 655,
#    'biomass': 495,
#    'coal': 1517,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 2790,
#    'gas': 11269,
#    'oil': 184,
#    'unknown': 3614,
#    'hydro discharge': -530,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 53,
#    'CH': 422,
#    'FR': 1033,
#    'GR': 0,
#    'ME': 103,
#    'MT': 0,
#    'SI': 1016,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 20,
#    'ME': 0,
#    'MT': 19,
#    'SI': 0,
#    'FR-COR': 26},
#   'fossilFreePercentage': 26,
#   'renewablePercentage': 20,
#   'powerConsumptionTotal': 22554,
#   'powerProductionTotal': 20523,
#   'powerImportTotal': 2626,
#   'powerExportTotal': 65,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T03:00:00.000Z',
#   'updatedAt': '2025-01-03T10:47:09.771Z',
#   'createdAt': '2024-12-31T03:44:25.469Z',
#   'powerConsumptionBreakdown': {'nuclear': 1555,
#    'geothermal': 650,
#    'biomass': 561,
#    'coal': 1773,
#    'wind': 288,
#    'solar': 0,
#    'hydro': 3108,
#    'gas': 11505,
#    'oil': 183,
#    'unknown': 3662,
#    'hydro discharge': 58,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 655,
#    'biomass': 495,
#    'coal': 1545,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 2890,
#    'gas': 11611,
#    'oil': 184,
#    'unknown': 3730,
#    'hydro discharge': -456,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 67,
#    'CH': 585,
#    'FR': 1149,
#    'GR': 0,
#    'ME': 149,
#    'MT': 0,
#    'SI': 826,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 35,
#    'ME': 0,
#    'MT': 26,
#    'SI': 0,
#    'FR-COR': 26},
#   'fossilFreePercentage': 27,
#   'renewablePercentage': 20,
#   'powerConsumptionTotal': 23343,
#   'powerProductionTotal': 21110,
#   'powerImportTotal': 2775,
#   'powerExportTotal': 87,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T04:00:00.000Z',
#   'updatedAt': '2025-01-03T10:47:09.771Z',
#   'createdAt': '2024-12-31T04:44:57.310Z',
#   'powerConsumptionBreakdown': {'nuclear': 1648,
#    'geothermal': 652,
#    'biomass': 565,
#    'coal': 1809,
#    'wind': 287,
#    'solar': 1,
#    'hydro': 3593,
#    'gas': 12658,
#    'oil': 191,
#    'unknown': 4038,
#    'hydro discharge': 73,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 654,
#    'biomass': 493,
#    'coal': 1621,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 3298,
#    'gas': 12653,
#    'oil': 187,
#    'unknown': 4061,
#    'hydro discharge': -161,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 52,
#    'CH': 469,
#    'FR': 1401,
#    'GR': 0,
#    'ME': 109,
#    'MT': 0,
#    'SI': 783,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 56,
#    'ME': 0,
#    'MT': 24,
#    'SI': 0,
#    'FR-COR': 25},
#   'fossilFreePercentage': 27,
#   'renewablePercentage': 20,
#   'powerConsumptionTotal': 25516,
#   'powerProductionTotal': 22968,
#   'powerImportTotal': 2814,
#   'powerExportTotal': 105,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T05:00:00.000Z',
#   'updatedAt': '2025-01-03T10:47:09.771Z',
#   'createdAt': '2024-12-31T05:45:09.857Z',
#   'powerConsumptionBreakdown': {'nuclear': 1845,
#    'geothermal': 653,
#    'biomass': 590,
#    'coal': 1932,
#    'wind': 358,
#    'solar': 0,
#    'hydro': 4551,
#    'gas': 14206,
#    'oil': 205,
#    'unknown': 4528,
#    'hydro discharge': 460,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 653,
#    'biomass': 490,
#    'coal': 1717,
#    'wind': 0,
#    'solar': 0,
#    'hydro': 4101,
#    'gas': 14043,
#    'oil': 194,
#    'unknown': 4514,
#    'hydro discharge': 305,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 67,
#    'CH': 658,
#    'FR': 1621,
#    'GR': 0,
#    'ME': 120,
#    'MT': 0,
#    'SI': 913,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 6,
#    'ME': 0,
#    'MT': 32,
#    'SI': 0,
#    'FR-COR': 31},
#   'fossilFreePercentage': 29,
#   'renewablePercentage': 22,
#   'powerConsumptionTotal': 29328,
#   'powerProductionTotal': 26017,
#   'powerImportTotal': 3379,
#   'powerExportTotal': 68,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T06:00:00.000Z',
#   'updatedAt': '2025-01-03T10:47:09.771Z',
#   'createdAt': '2024-12-31T06:45:39.797Z',
#   'powerConsumptionBreakdown': {'nuclear': 1815,
#    'geothermal': 652,
#    'biomass': 583,
#    'coal': 1932,
#    'wind': 320,
#    'solar': 2156,
#    'hydro': 5496,
#    'gas': 15012,
#    'oil': 215,
#    'unknown': 4828,
#    'hydro discharge': 881,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 651,
#    'biomass': 487,
#    'coal': 1775,
#    'wind': 0,
#    'solar': 2177,
#    'hydro': 4929,
#    'gas': 14885,
#    'oil': 201,
#    'unknown': 4810,
#    'hydro discharge': 680,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 70,
#    'CH': 674,
#    'FR': 1715,
#    'GR': 0,
#    'ME': 94,
#    'MT': 0,
#    'SI': 913,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 123,
#    'ME': 0,
#    'MT': 17,
#    'SI': 0,
#    'FR-COR': 34},
#   'fossilFreePercentage': 35,
#   'renewablePercentage': 30,
#   'powerConsumptionTotal': 33889,
#   'powerProductionTotal': 30596,
#   'powerImportTotal': 3466,
#   'powerExportTotal': 174,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T07:00:00.000Z',
#   'updatedAt': '2025-01-03T11:45:42.468Z',
#   'createdAt': '2024-12-31T07:48:30.488Z',
#   'powerConsumptionBreakdown': {'nuclear': 1727,
#    'geothermal': 650,
#    'biomass': 590,
#    'coal': 1929,
#    'wind': 310,
#    'solar': 4095,
#    'hydro': 5775,
#    'gas': 15180,
#    'oil': 218,
#    'unknown': 4931,
#    'hydro discharge': 900,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 649,
#    'biomass': 485,
#    'coal': 1780,
#    'wind': 0,
#    'solar': 4090,
#    'hydro': 5211,
#    'gas': 15003,
#    'oil': 206,
#    'unknown': 4898,
#    'hydro discharge': 709,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 72,
#    'CH': 886,
#    'FR': 1793,
#    'GR': 0,
#    'ME': 119,
#    'MT': 0,
#    'SI': 473,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 15,
#    'ME': 0,
#    'MT': 23,
#    'SI': 0,
#    'FR-COR': 33},
#   'fossilFreePercentage': 39,
#   'renewablePercentage': 34,
#   'powerConsumptionTotal': 36305,
#   'powerProductionTotal': 33032,
#   'powerImportTotal': 3343,
#   'powerExportTotal': 70,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T08:00:00.000Z',
#   'updatedAt': '2025-01-03T12:46:18.203Z',
#   'createdAt': '2024-12-31T08:47:46.247Z',
#   'powerConsumptionBreakdown': {'nuclear': 1881,
#    'geothermal': 648,
#    'biomass': 576,
#    'coal': 1874,
#    'wind': 303,
#    'solar': 5930,
#    'hydro': 5478,
#    'gas': 14974,
#    'oil': 220,
#    'unknown': 4891,
#    'hydro discharge': 698,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 648,
#    'biomass': 483,
#    'coal': 1747,
#    'wind': 0,
#    'solar': 5810,
#    'hydro': 4900,
#    'gas': 14792,
#    'oil': 208,
#    'unknown': 4866,
#    'hydro discharge': 520,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 72,
#    'CH': 744,
#    'FR': 2205,
#    'GR': 100,
#    'ME': 118,
#    'MT': 0,
#    'SI': 318,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 25,
#    'SI': 0,
#    'FR-COR': 33},
#   'fossilFreePercentage': 41,
#   'renewablePercentage': 36,
#   'powerConsumptionTotal': 37473,
#   'powerProductionTotal': 33975,
#   'powerImportTotal': 3557,
#   'powerExportTotal': 58,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T09:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:11.475Z',
#   'createdAt': '2024-12-31T09:46:56.462Z',
#   'powerConsumptionBreakdown': {'nuclear': 1924,
#    'geothermal': 647,
#    'biomass': 562,
#    'coal': 1820,
#    'wind': 289,
#    'solar': 7189,
#    'hydro': 4961,
#    'gas': 14680,
#    'oil': 221,
#    'unknown': 4798,
#    'hydro discharge': 463,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 647,
#    'biomass': 483,
#    'coal': 1704,
#    'wind': 0,
#    'solar': 6982,
#    'hydro': 4436,
#    'gas': 14499,
#    'oil': 208,
#    'unknown': 4786,
#    'hydro discharge': 334,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 50,
#    'CH': 513,
#    'FR': 2327,
#    'GR': 94,
#    'ME': 85,
#    'MT': 0,
#    'SI': 470,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 29,
#    'SI': 0,
#    'FR-COR': 33},
#   'fossilFreePercentage': 43,
#   'renewablePercentage': 38,
#   'powerConsumptionTotal': 37555,
#   'powerProductionTotal': 34079,
#   'powerImportTotal': 3539,
#   'powerExportTotal': 62,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T10:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-31T10:47:03.758Z',
#   'powerConsumptionBreakdown': {'nuclear': 2020,
#    'geothermal': 647,
#    'biomass': 574,
#    'coal': 1824,
#    'wind': 337,
#    'solar': 7885,
#    'hydro': 4489,
#    'gas': 14375,
#    'oil': 222,
#    'unknown': 4660,
#    'hydro discharge': 257,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 647,
#    'biomass': 483,
#    'coal': 1659,
#    'wind': 0,
#    'solar': 7556,
#    'hydro': 3934,
#    'gas': 14168,
#    'oil': 209,
#    'unknown': 4645,
#    'hydro discharge': 142,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 70,
#    'CH': 597,
#    'FR': 2277,
#    'GR': 125,
#    'ME': 113,
#    'MT': 0,
#    'SI': 735,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 40,
#    'SI': 0,
#    'FR-COR': 28},
#   'fossilFreePercentage': 43,
#   'renewablePercentage': 38,
#   'powerConsumptionTotal': 37292,
#   'powerProductionTotal': 33443,
#   'powerImportTotal': 3916,
#   'powerExportTotal': 68,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T11:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-31T11:47:40.607Z',
#   'powerConsumptionBreakdown': {'nuclear': 2034,
#    'geothermal': 648,
#    'biomass': 559,
#    'coal': 1758,
#    'wind': 318,
#    'solar': 7928,
#    'hydro': 4093,
#    'gas': 14069,
#    'oil': 222,
#    'unknown': 4532,
#    'hydro discharge': 121,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 647,
#    'biomass': 483,
#    'coal': 1624,
#    'wind': 0,
#    'solar': 7602,
#    'hydro': 3630,
#    'gas': 13908,
#    'oil': 211,
#    'unknown': 4528,
#    'hydro discharge': -12,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 53,
#    'CH': 367,
#    'FR': 2381,
#    'GR': 94,
#    'ME': 82,
#    'MT': 0,
#    'SI': 740,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 29,
#    'SI': 0,
#    'FR-COR': 27},
#   'fossilFreePercentage': 43,
#   'renewablePercentage': 38,
#   'powerConsumptionTotal': 36282,
#   'powerProductionTotal': 32633,
#   'powerImportTotal': 3718,
#   'powerExportTotal': 56,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T12:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-31T12:45:51.790Z',
#   'powerConsumptionBreakdown': {'nuclear': 2002,
#    'geothermal': 647,
#    'biomass': 553,
#    'coal': 1705,
#    'wind': 291,
#    'solar': 7451,
#    'hydro': 4036,
#    'gas': 14126,
#    'oil': 225,
#    'unknown': 4560,
#    'hydro discharge': 104,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 647,
#    'biomass': 484,
#    'coal': 1617,
#    'wind': 0,
#    'solar': 7123,
#    'hydro': 3631,
#    'gas': 14006,
#    'oil': 214,
#    'unknown': 4558,
#    'hydro discharge': -51,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 189,
#    'CH': 367,
#    'FR': 2512,
#    'GR': 126,
#    'ME': 82,
#    'MT': 0,
#    'SI': 244,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 33,
#    'SI': 0,
#    'FR-COR': 16},
#   'fossilFreePercentage': 42,
#   'renewablePercentage': 37,
#   'powerConsumptionTotal': 35700,
#   'powerProductionTotal': 32280,
#   'powerImportTotal': 3519,
#   'powerExportTotal': 49,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T13:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:25.531Z',
#   'createdAt': '2024-12-31T13:50:58.277Z',
#   'powerConsumptionBreakdown': {'nuclear': 1817,
#    'geothermal': 647,
#    'biomass': 532,
#    'coal': 1665,
#    'wind': 245,
#    'solar': 6341,
#    'hydro': 4143,
#    'gas': 14532,
#    'oil': 223,
#    'unknown': 4677,
#    'hydro discharge': 131,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 647,
#    'biomass': 483,
#    'coal': 1642,
#    'wind': 5,
#    'solar': 6109,
#    'hydro': 3834,
#    'gas': 14414,
#    'oil': 218,
#    'unknown': 4686,
#    'hydro discharge': 43,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 306,
#    'FR': 2504,
#    'GR': 104,
#    'MT': 0,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0, 'FR': 0, 'GR': 0, 'MT': 33, 'FR-COR': 10},
#   'fossilFreePercentage': 40,
#   'renewablePercentage': 34,
#   'powerConsumptionTotal': 34953,
#   'powerProductionTotal': 32081,
#   'powerImportTotal': 2915,
#   'powerExportTotal': 43,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-01-03T14:00:00.000Z',
#   'updatedAt': '2025-01-03T13:45:11.475Z',
#   'createdAt': '2024-12-31T14:48:20.926Z',
#   'powerConsumptionBreakdown': {'nuclear': 1949,
#    'geothermal': 650,
#    'biomass': 531,
#    'coal': 1709,
#    'wind': 206,
#    'solar': 4780,
#    'hydro': 4553,
#    'gas': 15256,
#    'oil': 228,
#    'unknown': 4882,
#    'hydro discharge': 281,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 647,
#    'biomass': 485,
#    'coal': 1691,
#    'wind': 7,
#    'solar': 4550,
#    'hydro': 4232,
#    'gas': 15046,
#    'oil': 224,
#    'unknown': 4862,
#    'hydro discharge': 246,
#    'battery discharge': None},
#   'powerImportBreakdown': {'AT': 306, 'FR': 2646, 'GR': 93, 'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0, 'FR': 0, 'GR': 0, 'FR-COR': 10},
#   'fossilFreePercentage': 37,
#   'renewablePercentage': 31,
#   'powerConsumptionTotal': 35026,
#   'powerProductionTotal': 31990,
#   'powerImportTotal': 3045,
#   'powerExportTotal': 10,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'}]

# %%
import pandas as pd

# create separated dataframes to store variables with multiple fields

selected = ['powerConsumptionBreakdown', 'powerProductionBreakdown', 'powerImportBreakdown', 'powerExportBreakdown']
powerConsumptionBreakdown_df = pd.DataFrame(columns=['nuclear','geothermal','biomass','coal','wind','solar','hydro','gas','oil','unknown','hydro discharge','battery discharge'])
powerProductionBreakdown_df = pd.DataFrame(columns=['nuclear','geothermal','biomass','coal','wind','solar','hydro','gas','oil','unknown','hydro discharge','battery discharge'])
powerImportBreakdown_df = pd.DataFrame(columns=['AT','CH','FR','GR','ME','MT','SI','FR-COR'])
powerExportBreakdown_df = pd.DataFrame(columns=['AT','CH','FR','GR','ME','MT','SI','FR-COR'])
date_strings = list()

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

for i, time_step in enumerate(hystorical_data):
    powerConsumptionBreakdown_df.loc[i] = time_step['powerConsumptionBreakdown']
    powerProductionBreakdown_df.loc[i] = time_step['powerProductionBreakdown']
    powerImportBreakdown_df.loc[i] = time_step['powerImportBreakdown']
    powerExportBreakdown_df.loc[i] = time_step['powerExportBreakdown']
    date_strings.append(time_step['datetime'])

# Convert strings to datetime objects
date_time = [
    datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%fZ") for date_str in date_strings
]
powerConsumptionBreakdown_df
# Out:
#     nuclear  geothermal  biomass  coal  wind  solar  hydro    gas  oil  \
# 0      2487         645      549  1771   142   2744   5313  15903  235
# 1      2119         646      582  1871   121     81   6276  16560  243
# 2      1701         647      591  1947   129      4   6965  16906  248
# 3      1690         648      596  2000   175      0   6935  17003  251
# 4      1862         649      588  2001   208      0   6110  16684  246
# 5      2079         650      580  1921   208      0   5101  15794  238
# 6      1865         651      584  1901   254      0   4312  14644  230
# 7      2425         650      738  2355   860      0   4271  13608  214
# 8      1902         647      585  1871   325      0   3476  12098  193
# 9      1922         651      578  1811   325      0   3200  11514  188
# 10     1667         651      575  1786   326      0   3048  11251  184
# 11     1451         650      556  1734   268      0   2979  11156  182
# 12     1555         650      561  1773   288      0   3108  11505  183
# 13     1648         652      565  1809   287      1   3593  12658  191
# 14     1845         653      590  1932   358      0   4551  14206  205
# 15     1815         652      583  1932   320   2156   5496  15012  215
# 16     1727         650      590  1929   310   4095   5775  15180  218
# 17     1881         648      576  1874   303   5930   5478  14974  220
# 18     1924         647      562  1820   289   7189   4961  14680  221
# 19     2020         647      574  1824   337   7885   4489  14375  222
# 20     2034         648      559  1758   318   7928   4093  14069  222
# 21     2002         647      553  1705   291   7451   4036  14126  225
# 22     1817         647      532  1665   245   6341   4143  14532  223
# 23     1949         650      531  1709   206   4780   4553  15256  228
#
#     unknown  hydro discharge  battery discharge
# 0      4998              711                  0
# 1      5184             1199                  0
# 2      5305             1640                  0
# 3      5308             1609                  0
# 4      5144             1115                  0
# 5      4846              686                  1
# 6      4540              413                  1
# 7      4238              341                  0
# 8      3871               72                  0
# 9      3672               56                  0
# 10     3560               52                  0
# 11     3532               46                  0
# 12     3662               58                  0
# 13     4038               73                  0
# 14     4528              460                  0
# 15     4828              881                  0
# 16     4931              900                  0
# 17     4891              698                  0
# 18     4798              463                  0
# 19     4660              257                  0
# 20     4532              121                  0
# 21     4560              104                  0
# 22     4677              131                  0
# 23     4882              281                  0

# %%
powerProductionBreakdown_df
# Out:
#    nuclear  geothermal  biomass  coal  wind  solar  hydro    gas  oil  \
# 0     None         648      488  1757     0   2688   4828  15764  232
# 1     None         649      490  1829     0     68   5675  16435  241
# 2     None         650      492  1889     0      0   6398  16819  247
# 3     None         651      493  1911     0      0   6380  16868  248
# 4     None         652      494  1878     0      0   5579  16493  244
# 5     None         653      495  1812     0      0   4612  15627  235
# 6     None         653      495  1741     0      0   3894  14462  226
# 7     None         654      494  1674     0      0   3436  13035  206
# 8     None         654      496  1615     0      0   3102  11944  191
# 9     None         655      496  1560     0      0   2890  11474  188
# 10    None         655      496  1523     0      0   2793  11284  185
# 11    None         655      495  1517     0      0   2790  11269  184
# 12    None         655      495  1545     0      0   2890  11611  184
# 13    None         654      493  1621     0      0   3298  12653  187
# 14    None         653      490  1717     0      0   4101  14043  194
# 15    None         651      487  1775     0   2177   4929  14885  201
# 16    None         649      485  1780     0   4090   5211  15003  206
# 17    None         648      483  1747     0   5810   4900  14792  208
# 18    None         647      483  1704     0   6982   4436  14499  208
# 19    None         647      483  1659     0   7556   3934  14168  209
# 20    None         647      483  1624     0   7602   3630  13908  211
# 21    None         647      484  1617     0   7123   3631  14006  214
# 22    None         647      483  1642     5   6109   3834  14414  218
# 23    None         647      485  1691     7   4550   4232  15046  224
#
#     unknown  hydro discharge battery discharge
# 0      5003              506              None
# 1      5149              909              None
# 2      5264             1336              None
# 3      5266             1355              None
# 4      5115              948              None
# 5      4825              552              None
# 6      4520              304              None
# 7      4164              121              None
# 8      3880              -99              None
# 9      3714             -301              None
# 10     3626             -452              None
# 11     3614             -530              None
# 12     3730             -456              None
# 13     4061             -161              None
# 14     4514              305              None
# 15     4810              680              None
# 16     4898              709              None
# 17     4866              520              None
# 18     4786              334              None
# 19     4645              142              None
# 20     4528              -12              None
# 21     4558              -51              None
# 22     4686               43              None
# 23     4862              246              None

# %% [markdown]
# Visualize the results

# %%
def stacked_bar_chart(df, title):

    plt.figure(figsize=(14, 8))
    num_hours = len(df)

    # Plot a stacked bar chart for all columns
    bottom = 0
    for column in df.columns:
        # NB: not all the values are always present therefore a try\except block is needed
        try:
            plt.bar(range(num_hours), df[column], label=column, bottom=bottom)
            bottom += df[column]
        except:
            continue

    plt.xlabel('Hour')
    plt.ylabel('Power (MW)')
    plt.title(title)
    plt.legend()
    plt.show()

stacked_bar_chart(powerConsumptionBreakdown_df, 'Power consumption Breakdown')
stacked_bar_chart(powerProductionBreakdown_df, 'Power production Breakdown')
stacked_bar_chart(powerImportBreakdown_df, 'Power import Breakdown')
stacked_bar_chart(powerExportBreakdown_df, 'Power export Breakdown')

# %% [markdown]
# Now choose and endpoint of your choice, explore the data available and visualize it in a proper way.

# %% [markdown]
# # Part VII: choose your desired API

# %% [markdown]
# Connect to the RapidAPI website (https://rapidapi.com/hub) and take a free API of your choice and start experimenting. Have Fun! :)

# %%
import requests
import json
from IPython.display import HTML

url = "https://linkedin-data-api.p.rapidapi.com/search-jobs"

querystring = {"keywords":"energy engineer","locationId":"100565514","datePosted":"anyTime","jobType":"fullTime","experienceLevel":"entryLevel","onsiteRemote":"hybrid","sort":"mostRelevant"}

headers = {
	"x-rapidapi-key": "4891ada879msh2df5f4e55651a2cp1eef8bjsn3946c3dbe6ab",
	"x-rapidapi-host": "linkedin-data-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()

# %%
# Visualize results
jobs = data.get('data', [])

# %%
def create_img_tag(logo_url):
    if logo_url:
        return f'<img src="{logo_url}" width="100" />'
    return ''

records = []
for job in jobs:
    company_info = job.get('company', {})
    logo_url = company_info.get('logo', '')
    
    records.append({
        'ID': job.get('id', ''),
        'Title': job.get('title', ''),
        'Company Name': company_info.get('name', ''),
        'Location': job.get('location', ''),
        'Posted At': job.get('postAt', ''),
        'URL': job.get('url', ''),
        'Logo': create_img_tag(logo_url)
    })

# %%
df = pd.DataFrame(records)

# %%
html_table = df.to_html(index=False, escape=False)
HTML(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>Title</th>
#       <th>Company Name</th>
#       <th>Location</th>
#       <th>Posted At</th>
#       <th>URL</th>
#       <th>Logo (img)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4046727362</td>
#       <td>Energy Engineer - HVAC Energy Optimization & Asset Performance (m/f/x)</td>
#       <td>Siemens</td>
#       <td>Beersel, Flemish Region, Belgium (Hybrid)</td>
#       <td></td>
#       <td>https://www.linkedin.com/jobs/view/4046727362</td>
#       <td><img src="https://media.licdn.com/dms/image/v2/D4D0BAQFK_4wGnzwPTQ/company-logo_200_200/company-logo_200_200/0/1719931174735/siemens_logo?e=1744243200&v=beta&t=4Yb-3tNLhs4w2ImXs-iTlzbo1zoUW2Q6yNKW8dmXrtI" width="100" /></td>
#     </tr>
#     <tr>
#       <td>4057999053</td>
#       <td>Energy & Utilities Engineer</td>
#       <td>Agidens</td>
#       <td>Beerse, Flemish Region, Belgium (Hybrid)</td>
#       <td>2024-10-24 22:00:00 +0000 UTC</td>
#       <td>https://www.linkedin.com/jobs/view/4057999053</td>
#       <td><img src="https://media.licdn.com/dms/image/v2/D4E0BAQFiLVTdLFPHwA/company-logo_200_200/company-logo_200_200/0/1684139980723/agidens_logo?e=1744243200&v=beta&t=s7NqkrAf5m02lhzbL2dc_PYlLc8zBQ1KMMHJ4YKVB-0" width="100" /></td>
#     </tr>
#     <tr>
#       <td>4085524776</td>
#       <td>Sales Engineer - Industrial Energy</td>
#       <td>GT Connex</td>
#       <td>Brussels, Brussels Region, Belgium (Hybrid)</td>
#       <td>2024-11-26 05:28:31 +0000 UTC</td>
#       <td>https://www.linkedin.com/jobs/view/4085524776</td>
#       <td><img src="https://media.licdn.com/dms/image/v2/D4E0BAQHsaZpeHOmDXg/company-logo_200_200/company-logo_200_200/0/1725522141998/gt_connex_logo?e=1744243200&v=beta&t=zL7ooBRPal_mUXPfYK3UXzPi7Empo7C_Msj_CgNkBCU" width="100" /></td>
#     </tr>
#   </tbody>
# </table>
